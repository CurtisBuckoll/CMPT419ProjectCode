# %%
# !pip install --upgrade pip
# !pip install tensorflow-gpu
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/54/0c/d01aa759fdc501a58f431eb594a17495f15b88da142ce14b5845662c13f3/pip-20.0.2-py2.py3-none-any.whl (1.4MB)
#      |████████████████████████████████| 1.4MB 26.4MB/s
# Installing collected packages: pip
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# Successfully installed pip-20.0.2
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (421.8 MB)
#      |████████████████████████████████| 421.8 MB 3.7 kB/s
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.18.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.1.8)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.2.2)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.10.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.8.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.9.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.0)
# Collecting tensorboard<2.2.0,>=2.1.0
#   Downloading tensorboard-2.1.1-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 80.6 MB/s
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Downloading tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448 kB)
#      |████████████████████████████████| 448 kB 69.9 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.0.8)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.4.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.34.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow-gpu) (45.2.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2.21.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.7.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.0.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu) (2.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.1.0)
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 2.1.1 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 2.1.0 which is incompatible.
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow~=2.1.0, but you'll have tensorflow 1.15.0 which is incompatible.
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow-addons~=0.7.0, but you'll have tensorflow-addons 0.8.3 which is incompatible.
# Installing collected packages: tensorboard, tensorflow-estimator, tensorflow-gpu
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
# Successfully installed tensorboard-2.1.1 tensorflow-estimator-2.1.0 tensorflow-gpu-2.1.0

# %%
# SET UP

# Data loader
import tensorflow as tf
print(tf.__version__)
from glob import glob
import numpy as np
import random
import scipy
import os
import cv2 as cv
from tensorflow import keras

# Network
#from keras.layers import Input, Conv2D, Conv2DTranspose, Concatenate
from tensorflow.keras.applications.vgg19 import VGG19
#from keras.models import Model

from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, UpSampling2D, Conv2DTranspose, Reshape, Dropout, concatenate, Concatenate, multiply, add, MaxPooling2D, Lambda, Activation, subtract, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
#from keras_contrib.layers.normalization import InstanceNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers.advanced_activations import LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import imageio
from tensorflow.python.keras import backend as K
from tensorflow.keras.models import Model
#from data_load import Dataloader
from scipy import misc
#from glob import glob
#import tensorflow as tf
import numpy as np
import scipy
import platform
#import keras
import os
import random
#import Network
#import utls

# Access Drive
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
drive.mount('/content/drive')
# Out:
# 2.1.0
# Using TensorFlow backend.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#filep = '/content/drive/My Drive/726FinalProj/dataset/train_test/*.png'
# ==================================================================
# PARAMS
ROOT_DIR = '/content/drive/My Drive/726FinalProj'
DATA_FOLDER_HI = '/high' #'/high_small_size'
DATA_FOLDER_LO = '/low'  #'/low_small_size'
BATCH_SIZE = 8 # original: 16
NUM_EPOCHS = 20  # original: 5
STEPS_PER_EPOCH = 186  # num_samples // batch_size, in general, for our data should be 30.
img_rows = 256
img_cols = 256

BASE_LEARN_RATE    = 1*1e-03

LOAD_FROM_WEIGHTS  = False
MODEL_WEIGHTS_FILE = '80_lol_base.h5'
RESUMED_LEARN_RATE = 7.5471934e-11
# ==================================================================

# %%
# ------------------------------------------------------------------
def build_preprocess(input_shape):
    preprocess_input = Input(shape=input_shape, name='preprocess_input')
    H_j = preprocess_input
    H_concat = preprocess_input
    for m in range(8):
        H_j = Conv2D(32, (3, 3), use_bias=True, padding='same', activation='relu')(H_j)
        H_concat = Concatenate(axis=3)([H_concat, H_j])

    preprocess_output = Conv2D(3, (1, 1), use_bias=True, padding='same', activation=None)(H_concat)

    preprocess_model = Model(inputs=preprocess_input, outputs=preprocess_output, name='preprocess_model')
    preprocess_model.summary()
    return preprocess_model
# ------------------------------------------------------------------


# ------------------------------------------------------------------
# Logarithmic transformation part.
def build_log_model(input_shape):
    # We will hard code these layers logarithmic transform layers, 
    # # as it will be less error prone than trying to subclass from
    # Layer and writing our own. This forces n=4. If we want to
    # adjust it later we will have to adjust n accordingly.
    # note:         v = [1, 10, 100, 300],
    # implementing: log(1 + v[j] * log_transform_input) / log(1 + v[j])
    log_transform_input = Input(input_shape, name='log_input')
    M_j = []
    M_j.append(Lambda(lambda x: tf.math.log(1.0 + 1.0   * x) / tf.math.log(1.0 + 1.0  ))(log_transform_input))
    M_j.append(Lambda(lambda x: tf.math.log(1.0 + 10.0  * x) / tf.math.log(1.0 + 10.0 ))(log_transform_input))
    M_j.append(Lambda(lambda x: tf.math.log(1.0 + 100.0 * x) / tf.math.log(1.0 + 100.0))(log_transform_input))
    M_j.append(Lambda(lambda x: tf.math.log(1.0 + 300.0 * x) / tf.math.log(1.0 + 300.0))(log_transform_input))
    M = Concatenate(axis=3)(M_j)

    M = Conv2D(filters=32, kernel_size=(1, 1), activation='relu', use_bias=True)(M)
    log_transform_output = Conv2D(3, (3, 3), use_bias=True, padding='same', activation=None)(M)

    log_transform_model = Model(inputs=log_transform_input, outputs=log_transform_output, name='log_model')
    log_transform_model.summary()
    return log_transform_model
# ------------------------------------------------------------------

class Dataloader():
    def __init__(self, dataset_name, crop_shape=(256, 256)):
        self.dataset_name = dataset_name
        self.crop_shape = crop_shape

    def imread_color(self, path):
        img = cv.imread(path, cv.IMREAD_COLOR | cv.IMREAD_ANYDEPTH) /255.
        b, g, r = cv.split(img)
        img_rgb = cv.merge([r, g, b])
        return img_rgb

    def imwrite(self, path, img):
        r, g, b = cv.split(img)
        img_rgb = cv.merge([b, g, r])
        cv.imwrite(path, img_rgb)

    def load_data(self, batch_size=16):
        path = glob(ROOT_DIR + '/dataset/combined' + DATA_FOLDER_HI + '/*.png')
        self.n_batches = int(len(path) / batch_size)
        while 1:
            random.shuffle(path)
            for i in range(self.n_batches - 1):
                batch_path = path[i * batch_size:(i + 1) * batch_size]
                input_imgs = np.empty((batch_size, self.crop_shape[0], self.crop_shape[1], 6), dtype="float32")
                gt = np.empty((batch_size, self.crop_shape[0], self.crop_shape[1], 3), dtype="float32")

                number = 0
                for img_B_path in batch_path:
                    img_B = self.imread_color(img_B_path)

                    path_split = os.path.split(img_B_path)
                    path_prefix = os.path.split(path_split[0])
                    path_A = path_prefix[0] + DATA_FOLDER_LO + '/' + path_split[1]

                    # path_mid = os.path.split(img_B_path)
                    # path_A_1 = path_mid[0] + '_' + self.dataset_name
                    # path_A = os.path.join(path_A_1, path_mid[1])
                    
                    img_A = self.imread_color(path_A)

                    nw = random.randint(0, img_B.shape[0] - self.crop_shape[0])
                    nh = random.randint(0, img_B.shape[1] - self.crop_shape[1])

                    crop_img_A = img_A[nw:nw + self.crop_shape[0], nh:nh + self.crop_shape[1], :]
                    crop_img_B = img_B[nw:nw + self.crop_shape[0], nh:nh + self.crop_shape[1],:]
                    
                    # im = Image.fromarray(crop_img_A)
                    # im.show()
                    # im = Image.fromarray(crop_img_B)
                    # im.show()

                    if np.random.randint(2, size=1)[0] == 1:  # random flip
                        crop_img_A = np.flipud(crop_img_A)
                        crop_img_B = np.flipud(crop_img_B)
                    if np.random.randint(2, size=1)[0] == 1:
                        crop_img_A = np.fliplr(crop_img_A)
                        crop_img_B = np.fliplr(crop_img_B)
                    if np.random.randint(2, size=1)[0] == 1:  # random transpose
                        crop_img_A = np.transpose(crop_img_A, (1, 0, 2))
                        crop_img_B = np.transpose(crop_img_B, (1, 0, 2))

                    input_imgs[number, :, :, :] = np.concatenate([crop_img_A, crop_img_B], axis=-1)
                    gt[number, :, :, :] = crop_img_B
                    number += 1
                yield input_imgs, gt

def build_vgg():
    vgg_model = VGG19(include_top=False, weights='imagenet')
    vgg_model.trainable = False
    return Model(inputs=vgg_model.input, outputs=vgg_model.get_layer('block3_conv4').output)

def build_mbllen(input_shape):

    def EM(input, kernal_size, channel):
        conv_1 = Conv2D(channel, (3, 3), activation='relu', padding='same', data_format='channels_last')(input)
        conv_2 = Conv2D(channel, (kernal_size, kernal_size), activation='relu', padding='valid', data_format='channels_last')(conv_1)
        conv_3 = Conv2D(channel*2, (kernal_size, kernal_size), activation='relu', padding='valid', data_format='channels_last')(conv_2)
        conv_4 = Conv2D(channel*4, (kernal_size, kernal_size), activation='relu', padding='valid', data_format='channels_last')(conv_3)
        conv_5 = Conv2DTranspose(channel*2, (kernal_size, kernal_size), activation='relu', padding='valid', data_format='channels_last')(conv_4)
        conv_6 = Conv2DTranspose(channel, (kernal_size, kernal_size), activation='relu', padding='valid', data_format='channels_last')(conv_5)
        res = Conv2DTranspose(3, (kernal_size, kernal_size), activation='relu', padding='valid', data_format='channels_last')(conv_6)
        return res

    inputs = Input(shape=input_shape)
    FEM = Conv2D(32, (3, 3), activation='relu', padding='same', data_format='channels_last')(inputs)
    EM_com = EM(FEM, 5, 8)

    for j in range(3):
        for i in range(0, 3):
            FEM = Conv2D(32, (3, 3), activation='relu', padding='same', data_format='channels_last')(FEM)
            EM1 = EM(FEM, 5, 8)
            EM_com = Concatenate(axis=3)([EM_com, EM1])

    outputs = Conv2D(3, (1, 1), activation='relu', padding='same', data_format='channels_last')(EM_com)
    return Model(inputs, outputs)

def bright_mae(y_true, y_pred):
    return K.mean(K.abs(y_pred[:,:,:,:3] - y_true[:,:,:,:3]))

def bright_mse(y_true, y_pred):
    return K.mean((y_pred[:,:,:,:3] - y_true[:,:,:,:3])**2)

def bright_AB(y_true, y_pred):
            return K.abs(K.mean(y_true[:,:,:,:3])-K.mean(y_pred[:,:,:,:3]))

def log10(x):
    numerator = K.log(x)
    denominator = K.log(K.constant(10, dtype=numerator.dtype))
    return numerator / denominator

def bright_psnr(y_true, y_pred):
    mse = K.mean((K.abs(y_pred[:,:,:,:3] - y_true[:,:,:,:3])) ** 2)
    max_num = 1.0
    psnr = 10 * log10(max_num ** 2 / mse)
    return psnr

def _tf_fspecial_gauss(size, sigma):
    """Function to mimic the 'fspecial' gaussian MATLAB function
    """
    x_data, y_data = np.mgrid[-size//2 + 1:size//2 + 1, -size//2 + 1:size//2 + 1]

    x_data = np.expand_dims(x_data, axis=-1)
    x_data = np.expand_dims(x_data, axis=-1)

    y_data = np.expand_dims(y_data, axis=-1)
    y_data = np.expand_dims(y_data, axis=-1)

    x = tf.constant(x_data, dtype=tf.float32)
    y = tf.constant(y_data, dtype=tf.float32)

    g = tf.exp(-((x**2 + y**2)/(2.0*sigma**2)))
    return g / tf.reduce_sum(g)

def tf_ssim(img1, img2, cs_map=False, mean_metric=True, size=11, sigma=1.5):
    window = _tf_fspecial_gauss(size, sigma) # window shape [size, size]
    K1 = 0.01
    K2 = 0.03
    L = 1  # depth of image (255 in case the image has a differnt scale)
    C1 = (K1*L)**2
    C2 = (K2*L)**2
    mu1 = tf.nn.conv2d(img1, window, strides=[1,1,1,1], padding='VALID')
    mu2 = tf.nn.conv2d(img2, window, strides=[1,1,1,1],padding='VALID')
    mu1_sq = mu1*mu1
    mu2_sq = mu2*mu2
    mu1_mu2 = mu1*mu2
    sigma1_sq = tf.nn.conv2d(img1*img1, window, strides=[1,1,1,1],padding='VALID') - mu1_sq
    sigma2_sq = tf.nn.conv2d(img2*img2, window, strides=[1,1,1,1],padding='VALID') - mu2_sq
    sigma12 = tf.nn.conv2d(img1*img2, window, strides=[1,1,1,1],padding='VALID') - mu1_mu2
    if cs_map:
        value = (((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2)),
                        (2.0*sigma12 + C2)/(sigma1_sq + sigma2_sq + C2))
    else:
        value = ((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2))

    if mean_metric:
        value = tf.reduce_mean(value)
    return value

def tf_ms_ssim(img1, img2, mean_metric=True, level=5):
    weight = tf.constant([0.0448, 0.2856, 0.3001, 0.2363, 0.1333], dtype=tf.float32)
    mssim = []
    mcs = []
    for l in range(level):
        ssim_map, cs_map = tf_ssim(img1, img2, cs_map=True, mean_metric=False)
        mssim.append(tf.reduce_mean(ssim_map))
        mcs.append(tf.reduce_mean(cs_map))
        filtered_im1 = tf.nn.avg_pool(img1, [1,2,2,1], [1,2,2,1], padding='SAME')
        filtered_im2 = tf.nn.avg_pool(img2, [1,2,2,1], [1,2,2,1], padding='SAME')
        img1 = filtered_im1
        img2 = filtered_im2

    # list to tensor of dim D+1
    mssim = tf.stack(mssim, axis=0)
    mcs = tf.stack(mcs, axis=0)

    value = (tf.reduce_prod(mcs[0:level-1]**weight[0:level-1])*
                                    (mssim[level-1]**weight[level-1]))

    if mean_metric:
        value = tf.reduce_mean(value)
    return value

def bright_SSIM(y_true, y_pred):
    SSIM_loss = tf_ssim(tf.expand_dims(y_pred[:,:,:,0], -1), tf.expand_dims(y_true[:,:,:,0], -1))+tf_ssim(tf.expand_dims(y_pred[:,:,:,1], -1), tf.expand_dims(y_true[:,:,:,1], -1)) + tf_ssim(tf.expand_dims(y_pred[:,:,:,2], -1), tf.expand_dims(y_true[:,:,:,2], -1))
    return SSIM_loss/3

def psnr_cau(y_true, y_pred):
    mse = np.mean((np.abs(y_pred - y_true)) ** 2)
    max_num = 1.0
    psnr = 10 * np.log10(max_num ** 2 / mse)
    return psnr

def save_model(model, name, epoch, batch_i):
    modelname = './Res_models/' + str(epoch) + '_' + str(batch_i) + name + '.h5'
    model.save_weights(modelname)

def imread_color(path):
    img = cv.imread(path, cv.IMREAD_COLOR | cv.IMREAD_ANYDEPTH) / 255.
    b, g, r = cv.split(img)
    img_rgb = cv.merge([r, g, b])
    return img_rgb
    # return scipy.misc.imread(path, mode='RGB').astype(np.float) / 255.

def imwrite(path, img):
    r, g, b = cv.split(img*255)
    img_rgb = cv.merge([b, g, r])
    cv.imwrite(path, img_rgb)
    # scipy.misc.toimage(img * 255, high=255, low=0, cmin=0, cmax=255).save(path)

def range_scale(x):
    return x * 2 - 1.

# %%
def my_loss(y_true, y_pred):
    MAE_loss = K.mean(K.abs(y_pred[:,:,:,:3] - y_true))
    SSIM_loss = tf_ssim(tf.expand_dims(y_pred[:, :, :, 0], -1),tf.expand_dims(y_true[:, :, :, 0], -1)) + tf_ssim(
        tf.expand_dims(y_pred[:, :, :, 1], -1), tf.expand_dims(y_true[:, :, :, 1], -1)) + tf_ssim(
        tf.expand_dims(y_pred[:, :, :, 2], -1), tf.expand_dims(y_true[:, :, :, 2], -1))
    VGG_loss = K.mean(K.abs(y_pred[:, :, :, 3:19] - y_pred[:, :, :, 19:35]))

    percent = 0.4
    index = int(256 * 256 * percent - 1)
    gray1 = 0.39 * y_pred[:, :, :, 0] + 0.5 * y_pred[:, :, :, 1] + 0.11 * y_pred[:, :, :, 2]
    gray = tf.reshape(gray1, [-1, 256 * 256])
    gray_sort = tf.nn.top_k(-gray, 256 * 256)[0]
    yu = gray_sort[:, index]
    yu = tf.expand_dims(tf.expand_dims(yu, -1), -1)
    mask = tf.dtypes.cast((gray1 <= yu), tf.float32)
    mask1 = tf.expand_dims(mask, -1)
    mask = tf.concat([mask1, mask1, mask1], -1)

    low_fake_clean = tf.multiply(mask, y_pred[:, :, :, :3])
    high_fake_clean = tf.multiply(1 - mask, y_pred[:, :, :, :3])
    low_clean = tf.multiply(mask, y_true[:, :, :, :])
    high_clean = tf.multiply(1 - mask, y_true[:, :, :, :])
    Region_loss = K.mean(K.abs(low_fake_clean - low_clean) * 4 + K.abs(high_fake_clean - high_clean))

    loss = MAE_loss + VGG_loss/3. + 3 - SSIM_loss + Region_loss
    return loss

if not os.path.isdir(ROOT_DIR + '/val_images'):
    os.makedirs(ROOT_DIR + '/val_images')
if not os.path.isdir(ROOT_DIR + '/logs'):
    os.makedirs(ROOT_DIR + '/logs')
if not os.path.isdir(ROOT_DIR + '/models_log'):
    os.makedirs(ROOT_DIR + '/models_log')

def f1(x):
    return x[:, :, :, :3]

def f2(x):
    return x[:, :, :, 3:]

def f3(x):
    return tf.reshape(x,[-1, 256, 256, 16])

img_channels = 3
crop_shape = (img_rows, img_cols, img_channels)
input_shape = (img_rows, img_cols, img_channels*2)
dataset_name = 'lol'
data_loader = Dataloader(dataset_name=dataset_name, crop_shape=(img_rows, img_cols))

# ==================================================================
# Build the network
mbllen = build_mbllen(crop_shape)
# mbllen.load_weights('./1_dark2_color_identity_param.h5')

Input_MBLLEN = Input(shape=input_shape)
img_A = Lambda(f1)(Input_MBLLEN)
img_B = Lambda(f2)(Input_MBLLEN)

# VGG19 feature, content loss
vgg = build_vgg()
vgg.trainable = False

# ------------------------------
# Log Part, added by me.
log_transform = build_log_model(crop_shape)
img_A = log_transform(img_A)
# -------------------------------

fake_B = mbllen(img_A)
vgg_fake = Lambda(range_scale)(fake_B)
fake_features = vgg(vgg_fake)
fake_features = Lambda(f3)(fake_features)

img_B_vgg = Lambda(range_scale)(img_B)
imgb_features = vgg(img_B_vgg)
imgb_features = Lambda(f3)(imgb_features)

output_com = concatenate([fake_B, fake_features, imgb_features], axis=3)

if LOAD_FROM_WEIGHTS == True:
  start_learn_rate = RESUMED_LEARN_RATE
else:
  start_learn_rate = BASE_LEARN_RATE

opt = Adam(lr=start_learn_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
combined = Model(inputs=Input_MBLLEN, outputs=output_com)
combined.compile(loss=my_loss,
                 metrics=[bright_mae, bright_mse, bright_psnr, bright_SSIM, bright_AB],
                 optimizer=opt)

# plot_model(mbllen, to_file='./model.png', show_shapes=True)
combined.summary()

# ==================================================================
#
def scheduler(epoch):
    lr = K.eval(combined.optimizer.lr)
    print("LR =", lr)
    lr = lr * 0.99
    return lr

# we will use this sequence for generating the random patch positions so that they are the same for each epoch
# patch_positions = []
num_epoch = 0
class Show_History(keras.callbacks.Callback):
    def on_epoch_end(self, val_loss=None, logs=None):
        # save model
        global num_epoch
        global dataset_name
        global img_rows
        global img_cols
        global mbllen
        num_epoch += 1
        modelname = ROOT_DIR + '/models_log/' + dataset_name + '/' + str(num_epoch) + '_' + dataset_name + '_base.h5'
        mbllen.save_weights(modelname)

        # test val data
        path = glob(ROOT_DIR + '/dataset/eval15/high/*.png')
        number = 0
        psnr_ave = 0


        for i in range(len(path)):
            if i>15:
                break

            img_B_path = path[i]
            img_B = imread_color(img_B_path)

            # path_mid = os.path.split(img_B_path)
            # path_A_1 = path_mid[0] + '_' + dataset_name
            # path_A = os.path.join(path_A_1, path_mid[1])

            path_split = os.path.split(img_B_path)
            path_prefix = os.path.split(path_split[0])
            path_A = path_prefix[0] + '/low/' + path_split[1]

            img_A = imread_color(path_A)

            nw = random.randint(0, img_A.shape[0] - img_rows)
            nh = random.randint(0, img_A.shape[1] - img_cols)

            crop_img_A = img_A[nw:nw + img_rows, nh:nh + img_cols, :]
            crop_img_B = img_B[nw:nw + img_rows, nh:nh + img_cols, :]

            crop_img_A = crop_img_A[np.newaxis, :]
            crop_img_B = crop_img_B[np.newaxis, :]

            fake_B = mbllen.predict(crop_img_A)
            identy_B = mbllen.predict(crop_img_B)

            out_img = np.concatenate([crop_img_A, fake_B, crop_img_B, identy_B], axis=2)
            out_img = out_img[0, :, :, :]

            fake_B = fake_B[0, :, :, :]
            img_B = crop_img_B[0, :, :, :]

            clean_psnr = psnr_cau(fake_B, img_B)
            L_psnr = ("%.4f" % clean_psnr)

            number += 1
            psnr_ave += clean_psnr

            im_name = path_split[1].split('.')[0]
            filename = os.path.basename(path[i])
            img_name = ROOT_DIR + '/val_images_log/' + str(num_epoch) + '_' + im_name + '_' + L_psnr + '_' + filename
            imwrite(img_name, out_img)
        psnr_ave /= number
        print('------------------------------------------------')
        print("[Epoch %d]  [PSNR_AVE :%f]" % (num_epoch,  psnr_ave))
        print('------------------------------------------------')

    def on_batch_end(self, batch, logs={}):
        print(' - LR = ', K.eval(self.model.optimizer.lr))

# ==================================================================
#
show_history = Show_History()
change_lr = LearningRateScheduler(scheduler)
#tbCallBack = keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=0, write_graph=True, write_images=False,
#                                         embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None)
nanstop = keras.callbacks.TerminateOnNaN()
reducelearate = keras.callbacks.ReduceLROnPlateau(monitor='lr', factor=0.5, patience=2, min_lr=1e-10)
earlystop = keras.callbacks.EarlyStopping(monitor='lr', min_delta=3, patience=0, verbose=0, mode='min')

if LOAD_FROM_WEIGHTS:
  mbllen.load_weights(ROOT_DIR + '/models/lol/' + MODEL_WEIGHTS_FILE)

combined.fit_generator(
        data_loader.load_data(BATCH_SIZE),
        steps_per_epoch=STEPS_PER_EPOCH, # num_samples // batch_size
        epochs=NUM_EPOCHS,
        callbacks=[show_history, change_lr, nanstop, reducelearate])
print('Done!')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 2s 0us/step
# Model: "log_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# log_input (InputLayer)          [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 256, 256, 3)  0           log_input[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 256, 256, 3)  0           log_input[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 256, 256, 3)  0           log_input[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 256, 256, 3)  0           log_input[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 256, 256, 12) 0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
#                                                                  lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 256, 256, 32) 416         concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 256, 256, 3)  867         conv2d_51[0][0]
# ==================================================================================================
# Total params: 1,283
# Trainable params: 1,283
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 6) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 256, 256, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# log_model (Model)               (None, 256, 256, 3)  1283        lambda[0][0]
# __________________________________________________________________________________________________
# model (Model)                   (None, 256, 256, 3)  450171      log_model[1][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 256, 256, 3)  0           model[1][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 256, 256, 3)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 multiple             2325568     lambda_6[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 256, 256, 16) 0           model_1[1][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 256, 256, 16) 0           model_1[2][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 256, 256, 35) 0           model[1][0]
#                                                                  lambda_7[0][0]
#                                                                  lambda_9[0][0]
# ==================================================================================================
# Total params: 2,777,022
# Trainable params: 451,454
# Non-trainable params: 2,325,568
# __________________________________________________________________________________________________
# WARNING:tensorflow:From <ipython-input-7-c58a3994b21a>:193: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 186 steps
# LR = 0.001
# Epoch 1/20
#  - LR =  0.0009900001
#   1/186 [..............................] - ETA: 43:35 - loss: 6.4582 - bright_mae: 0.4118 - bright_mse: 0.2408 - bright_psnr: 6.1835 - bright_SSIM: 0.0274 - bright_AB: 0.4118 - LR =  0.0009900001
#   2/186 [..............................] - ETA: 28:43 - loss: 6.2928 - bright_mae: 0.3858 - bright_mse: 0.2091 - bright_psnr: 6.8475 - bright_SSIM: 0.0930 - bright_AB: 0.3828 - LR =  0.0009900001
#   3/186 [..............................] - ETA: 35:58 - loss: 6.0831 - bright_mae: 0.3794 - bright_mse: 0.2070 - bright_psnr: 6.8738 - bright_SSIM: 0.1840 - bright_AB: 0.2993 - LR =  0.0009900001
#   4/186 [..............................] - ETA: 36:22 - loss: 5.9636 - bright_mae: 0.3869 - bright_mse: 0.2096 - bright_psnr: 6.8134 - bright_SSIM: 0.2125 - bright_AB: 0.3258 - LR =  0.0009900001
#   5/186 [..............................] - ETA: 36:02 - loss: 5.7517 - bright_mae: 0.3679 - bright_mse: 0.1941 - bright_psnr: 7.2080 - bright_SSIM: 0.2419 - bright_AB: 0.3128 - LR =  0.0009900001
#   6/186 [..............................] - ETA: 39:22 - loss: 5.7030 - bright_mae: 0.3549 - bright_mse: 0.1848 - bright_psnr: 7.4386 - bright_SSIM: 0.2502 - bright_AB: 0.3031 - LR =  0.0009900001
#   7/186 [>.............................] - ETA: 38:39 - loss: 5.6680 - bright_mae: 0.3440 - bright_mse: 0.1783 - bright_psnr: 7.5978 - bright_SSIM: 0.2596 - bright_AB: 0.2930 - LR =  0.0009900001
#   8/186 [>.............................] - ETA: 37:58 - loss: 5.6144 - bright_mae: 0.3378 - bright_mse: 0.1736 - bright_psnr: 7.7128 - bright_SSIM: 0.2738 - bright_AB: 0.2750 - LR =  0.0009900001
#   9/186 [>.............................] - ETA: 37:30 - loss: 5.5882 - bright_mae: 0.3308 - bright_mse: 0.1684 - bright_psnr: 7.8527 - bright_SSIM: 0.2809 - bright_AB: 0.2644 - LR =  0.0009900001
#  10/186 [>.............................] - ETA: 37:02 - loss: 5.4953 - bright_mae: 0.3270 - bright_mse: 0.1652 - bright_psnr: 7.9326 - bright_SSIM: 0.2924 - bright_AB: 0.2617 - LR =  0.0009900001
#  11/186 [>.............................] - ETA: 37:37 - loss: 5.4403 - bright_mae: 0.3292 - bright_mse: 0.1671 - bright_psnr: 7.8753 - bright_SSIM: 0.2983 - bright_AB: 0.2683 - LR =  0.0009900001
#  12/186 [>.............................] - ETA: 37:20 - loss: 5.3873 - bright_mae: 0.3247 - bright_mse: 0.1643 - bright_psnr: 7.9494 - bright_SSIM: 0.3049 - bright_AB: 0.2651 - LR =  0.0009900001
#  13/186 [=>............................] - ETA: 36:41 - loss: 5.3128 - bright_mae: 0.3230 - bright_mse: 0.1632 - bright_psnr: 7.9693 - bright_SSIM: 0.3127 - bright_AB: 0.2638 - LR =  0.0009900001
#  14/186 [=>............................] - ETA: 36:05 - loss: 5.2623 - bright_mae: 0.3211 - bright_mse: 0.1624 - bright_psnr: 7.9850 - bright_SSIM: 0.3199 - bright_AB: 0.2615 - LR =  0.0009900001
#  15/186 [=>............................] - ETA: 35:38 - loss: 5.2160 - bright_mae: 0.3215 - bright_mse: 0.1630 - bright_psnr: 7.9644 - bright_SSIM: 0.3236 - bright_AB: 0.2628 - LR =  0.0009900001
#  16/186 [=>............................] - ETA: 35:15 - loss: 5.1464 - bright_mae: 0.3192 - bright_mse: 0.1608 - bright_psnr: 8.0261 - bright_SSIM: 0.3287 - bright_AB: 0.2622 - LR =  0.0009900001
#  17/186 [=>............................] - ETA: 34:56 - loss: 5.0919 - bright_mae: 0.3165 - bright_mse: 0.1595 - bright_psnr: 8.0575 - bright_SSIM: 0.3351 - bright_AB: 0.2610 - LR =  0.0009900001
#  18/186 [=>............................] - ETA: 34:37 - loss: 5.0497 - bright_mae: 0.3125 - bright_mse: 0.1564 - bright_psnr: 8.1544 - bright_SSIM: 0.3400 - bright_AB: 0.2573 - LR =  0.0009900001
#  19/186 [==>...........................] - ETA: 34:20 - loss: 5.0166 - bright_mae: 0.3124 - bright_mse: 0.1568 - bright_psnr: 8.1404 - bright_SSIM: 0.3446 - bright_AB: 0.2577 - LR =  0.0009900001
#  20/186 [==>...........................] - ETA: 34:13 - loss: 4.9939 - bright_mae: 0.3111 - bright_mse: 0.1561 - bright_psnr: 8.1555 - bright_SSIM: 0.3477 - bright_AB: 0.2547 - LR =  0.0009900001
#  21/186 [==>...........................] - ETA: 33:53 - loss: 4.9619 - bright_mae: 0.3086 - bright_mse: 0.1549 - bright_psnr: 8.1857 - bright_SSIM: 0.3532 - bright_AB: 0.2531 - LR =  0.0009900001
#  22/186 [==>...........................] - ETA: 33:38 - loss: 4.9173 - bright_mae: 0.3076 - bright_mse: 0.1533 - bright_psnr: 8.2336 - bright_SSIM: 0.3596 - bright_AB: 0.2539 - LR =  0.0009900001
#  23/186 [==>...........................] - ETA: 33:24 - loss: 4.8482 - bright_mae: 0.3010 - bright_mse: 0.1485 - bright_psnr: 8.4734 - bright_SSIM: 0.3715 - bright_AB: 0.2434 - LR =  0.0009900001
#  24/186 [==>...........................] - ETA: 33:34 - loss: 4.7965 - bright_mae: 0.2976 - bright_mse: 0.1456 - bright_psnr: 8.5810 - bright_SSIM: 0.3809 - bright_AB: 0.2392 - LR =  0.0009900001
#  25/186 [===>..........................] - ETA: 33:22 - loss: 4.7453 - bright_mae: 0.2932 - bright_mse: 0.1419 - bright_psnr: 8.7439 - bright_SSIM: 0.3876 - bright_AB: 0.2308 - LR =  0.0009900001
#  26/186 [===>..........................] - ETA: 33:05 - loss: 4.6830 - bright_mae: 0.2909 - bright_mse: 0.1394 - bright_psnr: 8.8370 - bright_SSIM: 0.3963 - bright_AB: 0.2291 - LR =  0.0009900001
#  27/186 [===>..........................] - ETA: 32:55 - loss: 4.6139 - bright_mae: 0.2852 - bright_mse: 0.1354 - bright_psnr: 9.0648 - bright_SSIM: 0.4062 - bright_AB: 0.2232 - LR =  0.0009900001
#  28/186 [===>..........................] - ETA: 32:43 - loss: 4.5583 - bright_mae: 0.2808 - bright_mse: 0.1322 - bright_psnr: 9.2215 - bright_SSIM: 0.4149 - bright_AB: 0.2186 - LR =  0.0009900001
#  29/186 [===>..........................] - ETA: 32:31 - loss: 4.5163 - bright_mae: 0.2785 - bright_mse: 0.1301 - bright_psnr: 9.2968 - bright_SSIM: 0.4217 - bright_AB: 0.2135 - LR =  0.0009900001
#  30/186 [===>..........................] - ETA: 32:15 - loss: 4.4655 - bright_mae: 0.2751 - bright_mse: 0.1276 - bright_psnr: 9.4116 - bright_SSIM: 0.4308 - bright_AB: 0.2080 - LR =  0.0009900001
#  31/186 [====>.........................] - ETA: 32:02 - loss: 4.4207 - bright_mae: 0.2711 - bright_mse: 0.1247 - bright_psnr: 9.5602 - bright_SSIM: 0.4384 - bright_AB: 0.2038 - LR =  0.0009900001
#  32/186 [====>.........................] - ETA: 31:44 - loss: 4.3744 - bright_mae: 0.2690 - bright_mse: 0.1228 - bright_psnr: 9.6383 - bright_SSIM: 0.4462 - bright_AB: 0.2025 - LR =  0.0009900001
#  33/186 [====>.........................] - ETA: 31:30 - loss: 4.3182 - bright_mae: 0.2644 - bright_mse: 0.1199 - bright_psnr: 9.8210 - bright_SSIM: 0.4549 - bright_AB: 0.1968 - LR =  0.0009900001
#  34/186 [====>.........................] - ETA: 31:37 - loss: 4.2746 - bright_mae: 0.2604 - bright_mse: 0.1172 - bright_psnr: 9.9870 - bright_SSIM: 0.4616 - bright_AB: 0.1912 - LR =  0.0009900001
#  35/186 [====>.........................] - ETA: 31:19 - loss: 4.2377 - bright_mae: 0.2579 - bright_mse: 0.1154 - bright_psnr: 10.0648 - bright_SSIM: 0.4675 - bright_AB: 0.1881 - LR =  0.0009900001
#  36/186 [====>.........................] - ETA: 31:04 - loss: 4.1959 - bright_mae: 0.2552 - bright_mse: 0.1132 - bright_psnr: 10.1814 - bright_SSIM: 0.4722 - bright_AB: 0.1829 - LR =  0.0009900001
#  37/186 [====>.........................] - ETA: 30:51 - loss: 4.1654 - bright_mae: 0.2523 - bright_mse: 0.1112 - bright_psnr: 10.2918 - bright_SSIM: 0.4771 - bright_AB: 0.1800 - LR =  0.0009900001
#  38/186 [=====>........................] - ETA: 30:37 - loss: 4.1278 - bright_mae: 0.2489 - bright_mse: 0.1090 - bright_psnr: 10.4235 - bright_SSIM: 0.4832 - bright_AB: 0.1760 - LR =  0.0009900001
#  39/186 [=====>........................] - ETA: 30:24 - loss: 4.0890 - bright_mae: 0.2468 - bright_mse: 0.1073 - bright_psnr: 10.5077 - bright_SSIM: 0.4897 - bright_AB: 0.1745 - LR =  0.0009900001
#  40/186 [=====>........................] - ETA: 30:23 - loss: 4.0628 - bright_mae: 0.2442 - bright_mse: 0.1056 - bright_psnr: 10.5962 - bright_SSIM: 0.4934 - bright_AB: 0.1702 - LR =  0.0009900001
#  41/186 [=====>........................] - ETA: 30:09 - loss: 4.0272 - bright_mae: 0.2422 - bright_mse: 0.1041 - bright_psnr: 10.6700 - bright_SSIM: 0.4987 - bright_AB: 0.1666 - LR =  0.0009900001
#  42/186 [=====>........................] - ETA: 29:54 - loss: 3.9906 - bright_mae: 0.2397 - bright_mse: 0.1023 - bright_psnr: 10.7784 - bright_SSIM: 0.5042 - bright_AB: 0.1632 - LR =  0.0009900001
#  43/186 [=====>........................] - ETA: 29:41 - loss: 3.9682 - bright_mae: 0.2379 - bright_mse: 0.1010 - bright_psnr: 10.8407 - bright_SSIM: 0.5077 - bright_AB: 0.1625 - LR =  0.0009900001
#  44/186 [======>.......................] - ETA: 29:28 - loss: 3.9402 - bright_mae: 0.2366 - bright_mse: 0.0998 - bright_psnr: 10.8931 - bright_SSIM: 0.5122 - bright_AB: 0.1620 - LR =  0.0009900001
#  45/186 [======>.......................] - ETA: 29:24 - loss: 3.9173 - bright_mae: 0.2345 - bright_mse: 0.0983 - bright_psnr: 10.9795 - bright_SSIM: 0.5150 - bright_AB: 0.1589 - LR =  0.0009900001
#  46/186 [======>.......................] - ETA: 29:09 - loss: 3.8935 - bright_mae: 0.2330 - bright_mse: 0.0971 - bright_psnr: 11.0439 - bright_SSIM: 0.5185 - bright_AB: 0.1574 - LR =  0.0009900001
#  47/186 [======>.......................] - ETA: 28:55 - loss: 3.8645 - bright_mae: 0.2313 - bright_mse: 0.0958 - bright_psnr: 11.1133 - bright_SSIM: 0.5229 - bright_AB: 0.1550 - LR =  0.0009900001
#  48/186 [======>.......................] - ETA: 28:46 - loss: 3.8457 - bright_mae: 0.2302 - bright_mse: 0.0948 - bright_psnr: 11.1547 - bright_SSIM: 0.5253 - bright_AB: 0.1536 - LR =  0.0009900001
#  49/186 [======>.......................] - ETA: 28:42 - loss: 3.8214 - bright_mae: 0.2295 - bright_mse: 0.0940 - bright_psnr: 11.1869 - bright_SSIM: 0.5290 - bright_AB: 0.1534 - LR =  0.0009900001
#  50/186 [=======>......................] - ETA: 28:27 - loss: 3.8002 - bright_mae: 0.2282 - bright_mse: 0.0929 - bright_psnr: 11.2362 - bright_SSIM: 0.5327 - bright_AB: 0.1526 - LR =  0.0009900001
#  51/186 [=======>......................] - ETA: 28:14 - loss: 3.7800 - bright_mae: 0.2277 - bright_mse: 0.0924 - bright_psnr: 11.2502 - bright_SSIM: 0.5356 - bright_AB: 0.1526 - LR =  0.0009900001
#  52/186 [=======>......................] - ETA: 28:06 - loss: 3.7538 - bright_mae: 0.2259 - bright_mse: 0.0913 - bright_psnr: 11.3091 - bright_SSIM: 0.5390 - bright_AB: 0.1504 - LR =  0.0009900001
#  53/186 [=======>......................] - ETA: 27:54 - loss: 3.7368 - bright_mae: 0.2246 - bright_mse: 0.0903 - bright_psnr: 11.3604 - bright_SSIM: 0.5417 - bright_AB: 0.1488 - LR =  0.0009900001
#  54/186 [=======>......................] - ETA: 27:42 - loss: 3.7144 - bright_mae: 0.2241 - bright_mse: 0.0898 - bright_psnr: 11.3726 - bright_SSIM: 0.5449 - bright_AB: 0.1492 - LR =  0.0009900001
#  55/186 [=======>......................] - ETA: 27:28 - loss: 3.6930 - bright_mae: 0.2228 - bright_mse: 0.0888 - bright_psnr: 11.4305 - bright_SSIM: 0.5483 - bright_AB: 0.1481 - LR =  0.0009900001
#  56/186 [========>.....................] - ETA: 27:15 - loss: 3.6737 - bright_mae: 0.2217 - bright_mse: 0.0880 - bright_psnr: 11.4758 - bright_SSIM: 0.5513 - bright_AB: 0.1456 - LR =  0.0009900001
#  57/186 [========>.....................] - ETA: 27:03 - loss: 3.6535 - bright_mae: 0.2202 - bright_mse: 0.0870 - bright_psnr: 11.5350 - bright_SSIM: 0.5543 - bright_AB: 0.1436 - LR =  0.0009900001
#  58/186 [========>.....................] - ETA: 26:49 - loss: 3.6320 - bright_mae: 0.2186 - bright_mse: 0.0860 - bright_psnr: 11.6035 - bright_SSIM: 0.5574 - bright_AB: 0.1414 - LR =  0.0009900001
#  59/186 [========>.....................] - ETA: 26:36 - loss: 3.6177 - bright_mae: 0.2174 - bright_mse: 0.0852 - bright_psnr: 11.6470 - bright_SSIM: 0.5599 - bright_AB: 0.1404 - LR =  0.0009900001
#  60/186 [========>.....................] - ETA: 26:23 - loss: 3.5988 - bright_mae: 0.2166 - bright_mse: 0.0844 - bright_psnr: 11.6846 - bright_SSIM: 0.5625 - bright_AB: 0.1392 - LR =  0.0009900001
#  61/186 [========>.....................] - ETA: 26:14 - loss: 3.5883 - bright_mae: 0.2166 - bright_mse: 0.0841 - bright_psnr: 11.6910 - bright_SSIM: 0.5640 - bright_AB: 0.1395 - LR =  0.0009900001
#  62/186 [=========>....................] - ETA: 26:02 - loss: 3.5735 - bright_mae: 0.2160 - bright_mse: 0.0835 - bright_psnr: 11.7144 - bright_SSIM: 0.5660 - bright_AB: 0.1395 - LR =  0.0009900001
#  63/186 [=========>....................] - ETA: 25:55 - loss: 3.5585 - bright_mae: 0.2151 - bright_mse: 0.0828 - bright_psnr: 11.7547 - bright_SSIM: 0.5679 - bright_AB: 0.1383 - LR =  0.0009900001
#  64/186 [=========>....................] - ETA: 25:42 - loss: 3.5405 - bright_mae: 0.2138 - bright_mse: 0.0819 - bright_psnr: 11.8077 - bright_SSIM: 0.5704 - bright_AB: 0.1371 - LR =  0.0009900001
#  65/186 [=========>....................] - ETA: 25:32 - loss: 3.5260 - bright_mae: 0.2124 - bright_mse: 0.0811 - bright_psnr: 11.8669 - bright_SSIM: 0.5725 - bright_AB: 0.1353 - LR =  0.0009900001
#  66/186 [=========>....................] - ETA: 25:25 - loss: 3.5117 - bright_mae: 0.2115 - bright_mse: 0.0804 - bright_psnr: 11.9047 - bright_SSIM: 0.5748 - bright_AB: 0.1348 - LR =  0.0009900001
#  67/186 [=========>....................] - ETA: 25:14 - loss: 3.4940 - bright_mae: 0.2104 - bright_mse: 0.0796 - bright_psnr: 11.9600 - bright_SSIM: 0.5768 - bright_AB: 0.1333 - LR =  0.0009900001
#  68/186 [=========>....................] - ETA: 25:02 - loss: 3.4815 - bright_mae: 0.2098 - bright_mse: 0.0791 - bright_psnr: 11.9838 - bright_SSIM: 0.5784 - bright_AB: 0.1328 - LR =  0.0009900001
#  69/186 [==========>...................] - ETA: 24:53 - loss: 3.4698 - bright_mae: 0.2091 - bright_mse: 0.0785 - bright_psnr: 12.0163 - bright_SSIM: 0.5800 - bright_AB: 0.1317 - LR =  0.0009900001
#  70/186 [==========>...................] - ETA: 24:40 - loss: 3.4517 - bright_mae: 0.2077 - bright_mse: 0.0777 - bright_psnr: 12.0919 - bright_SSIM: 0.5826 - bright_AB: 0.1301 - LR =  0.0009900001
#  71/186 [==========>...................] - ETA: 24:35 - loss: 3.4340 - bright_mae: 0.2068 - bright_mse: 0.0770 - bright_psnr: 12.1327 - bright_SSIM: 0.5852 - bright_AB: 0.1284 - LR =  0.0009900001
#  72/186 [==========>...................] - ETA: 24:22 - loss: 3.4204 - bright_mae: 0.2061 - bright_mse: 0.0765 - bright_psnr: 12.1616 - bright_SSIM: 0.5872 - bright_AB: 0.1280 - LR =  0.0009900001
#  73/186 [==========>...................] - ETA: 24:10 - loss: 3.4050 - bright_mae: 0.2056 - bright_mse: 0.0760 - bright_psnr: 12.1826 - bright_SSIM: 0.5894 - bright_AB: 0.1263 - LR =  0.0009900001
#  74/186 [==========>...................] - ETA: 23:59 - loss: 3.3868 - bright_mae: 0.2043 - bright_mse: 0.0752 - bright_psnr: 12.2487 - bright_SSIM: 0.5920 - bright_AB: 0.1248 - LR =  0.0009900001
#  75/186 [===========>..................] - ETA: 23:45 - loss: 3.3684 - bright_mae: 0.2028 - bright_mse: 0.0744 - bright_psnr: 12.3304 - bright_SSIM: 0.5947 - bright_AB: 0.1239 - LR =  0.0009900001
#  76/186 [===========>..................] - ETA: 23:31 - loss: 3.3553 - bright_mae: 0.2024 - bright_mse: 0.0740 - bright_psnr: 12.3447 - bright_SSIM: 0.5966 - bright_AB: 0.1230 - LR =  0.0009900001
#  77/186 [===========>..................] - ETA: 23:18 - loss: 3.3482 - bright_mae: 0.2025 - bright_mse: 0.0740 - bright_psnr: 12.3362 - bright_SSIM: 0.5977 - bright_AB: 0.1226 - LR =  0.0009900001
#  78/186 [===========>..................] - ETA: 23:08 - loss: 3.3309 - bright_mae: 0.2017 - bright_mse: 0.0734 - bright_psnr: 12.3697 - bright_SSIM: 0.6001 - bright_AB: 0.1215 - LR =  0.0009900001
#  79/186 [===========>..................] - ETA: 23:04 - loss: 3.3203 - bright_mae: 0.2009 - bright_mse: 0.0729 - bright_psnr: 12.4058 - bright_SSIM: 0.6016 - bright_AB: 0.1208 - LR =  0.0009900001
#  80/186 [===========>..................] - ETA: 22:54 - loss: 3.3073 - bright_mae: 0.2000 - bright_mse: 0.0723 - bright_psnr: 12.4481 - bright_SSIM: 0.6032 - bright_AB: 0.1197 - LR =  0.0009900001
#  81/186 [============>.................] - ETA: 22:51 - loss: 3.2955 - bright_mae: 0.1989 - bright_mse: 0.0716 - bright_psnr: 12.5055 - bright_SSIM: 0.6046 - bright_AB: 0.1183 - LR =  0.0009900001
#  82/186 [============>.................] - ETA: 22:40 - loss: 3.2797 - bright_mae: 0.1980 - bright_mse: 0.0711 - bright_psnr: 12.5442 - bright_SSIM: 0.6068 - bright_AB: 0.1174 - LR =  0.0009900001
#  83/186 [============>.................] - ETA: 22:28 - loss: 3.2663 - bright_mae: 0.1973 - bright_mse: 0.0706 - bright_psnr: 12.5799 - bright_SSIM: 0.6084 - bright_AB: 0.1160 - LR =  0.0009900001
#  84/186 [============>.................] - ETA: 22:20 - loss: 3.2590 - bright_mae: 0.1970 - bright_mse: 0.0703 - bright_psnr: 12.5892 - bright_SSIM: 0.6094 - bright_AB: 0.1150 - LR =  0.0009900001
#  85/186 [============>.................] - ETA: 22:07 - loss: 3.2437 - bright_mae: 0.1961 - bright_mse: 0.0698 - bright_psnr: 12.6309 - bright_SSIM: 0.6116 - bright_AB: 0.1142 - LR =  0.0009900001
#  86/186 [============>.................] - ETA: 21:58 - loss: 3.2355 - bright_mae: 0.1953 - bright_mse: 0.0693 - bright_psnr: 12.6615 - bright_SSIM: 0.6129 - bright_AB: 0.1131 - LR =  0.0009900001
#  87/186 [=============>................] - ETA: 21:48 - loss: 3.2273 - bright_mae: 0.1952 - bright_mse: 0.0691 - bright_psnr: 12.6602 - bright_SSIM: 0.6146 - bright_AB: 0.1132 - LR =  0.0009900001
#  88/186 [=============>................] - ETA: 21:38 - loss: 3.2145 - bright_mae: 0.1942 - bright_mse: 0.0685 - bright_psnr: 12.7197 - bright_SSIM: 0.6160 - bright_AB: 0.1119 - LR =  0.0009900001
#  89/186 [=============>................] - ETA: 21:35 - loss: 3.2036 - bright_mae: 0.1934 - bright_mse: 0.0680 - bright_psnr: 12.7592 - bright_SSIM: 0.6176 - bright_AB: 0.1115 - LR =  0.0009900001
#  90/186 [=============>................] - ETA: 21:22 - loss: 3.1916 - bright_mae: 0.1926 - bright_mse: 0.0675 - bright_psnr: 12.8005 - bright_SSIM: 0.6193 - bright_AB: 0.1106 - LR =  0.0009900001
#  91/186 [=============>................] - ETA: 21:08 - loss: 3.1785 - bright_mae: 0.1916 - bright_mse: 0.0670 - bright_psnr: 12.8525 - bright_SSIM: 0.6211 - bright_AB: 0.1099 - LR =  0.0009900001
#  92/186 [=============>................] - ETA: 21:00 - loss: 3.1665 - bright_mae: 0.1905 - bright_mse: 0.0664 - bright_psnr: 12.9167 - bright_SSIM: 0.6229 - bright_AB: 0.1092 - LR =  0.0009900001
#  93/186 [==============>...............] - ETA: 20:46 - loss: 3.1550 - bright_mae: 0.1900 - bright_mse: 0.0660 - bright_psnr: 12.9422 - bright_SSIM: 0.6244 - bright_AB: 0.1089 - LR =  0.0009900001
#  94/186 [==============>...............] - ETA: 20:32 - loss: 3.1439 - bright_mae: 0.1894 - bright_mse: 0.0656 - bright_psnr: 12.9696 - bright_SSIM: 0.6259 - bright_AB: 0.1081 - LR =  0.0009900001
#  95/186 [==============>...............] - ETA: 20:19 - loss: 3.1357 - bright_mae: 0.1891 - bright_mse: 0.0653 - bright_psnr: 12.9811 - bright_SSIM: 0.6268 - bright_AB: 0.1070 - LR =  0.0009900001
#  96/186 [==============>...............] - ETA: 20:08 - loss: 3.1254 - bright_mae: 0.1887 - bright_mse: 0.0650 - bright_psnr: 13.0017 - bright_SSIM: 0.6281 - bright_AB: 0.1063 - LR =  0.0009900001
#  97/186 [==============>...............] - ETA: 19:54 - loss: 3.1152 - bright_mae: 0.1880 - bright_mse: 0.0645 - bright_psnr: 13.0398 - bright_SSIM: 0.6297 - bright_AB: 0.1061 - LR =  0.0009900001
#  98/186 [==============>...............] - ETA: 19:41 - loss: 3.1068 - bright_mae: 0.1879 - bright_mse: 0.0643 - bright_psnr: 13.0454 - bright_SSIM: 0.6311 - bright_AB: 0.1059 - LR =  0.0009900001
#  99/186 [==============>...............] - ETA: 19:27 - loss: 3.1026 - bright_mae: 0.1873 - bright_mse: 0.0640 - bright_psnr: 13.0664 - bright_SSIM: 0.6316 - bright_AB: 0.1054 - LR =  0.0009900001
# 100/186 [===============>..............] - ETA: 19:21 - loss: 3.0911 - bright_mae: 0.1865 - bright_mse: 0.0635 - bright_psnr: 13.1098 - bright_SSIM: 0.6331 - bright_AB: 0.1046 - LR =  0.0009900001
# 101/186 [===============>..............] - ETA: 19:07 - loss: 3.0793 - bright_mae: 0.1860 - bright_mse: 0.0631 - bright_psnr: 13.1406 - bright_SSIM: 0.6348 - bright_AB: 0.1037 - LR =  0.0009900001
# 102/186 [===============>..............] - ETA: 18:53 - loss: 3.0752 - bright_mae: 0.1859 - bright_mse: 0.0630 - bright_psnr: 13.1354 - bright_SSIM: 0.6354 - bright_AB: 0.1042 - LR =  0.0009900001
# 103/186 [===============>..............] - ETA: 18:39 - loss: 3.0658 - bright_mae: 0.1854 - bright_mse: 0.0627 - bright_psnr: 13.1574 - bright_SSIM: 0.6367 - bright_AB: 0.1032 - LR =  0.0009900001
# 104/186 [===============>..............] - ETA: 18:26 - loss: 3.0559 - bright_mae: 0.1848 - bright_mse: 0.0623 - bright_psnr: 13.1838 - bright_SSIM: 0.6380 - bright_AB: 0.1028 - LR =  0.0009900001
# 105/186 [===============>..............] - ETA: 18:13 - loss: 3.0480 - bright_mae: 0.1843 - bright_mse: 0.0620 - bright_psnr: 13.2078 - bright_SSIM: 0.6391 - bright_AB: 0.1021 - LR =  0.0009900001
# 106/186 [================>.............] - ETA: 18:04 - loss: 3.0373 - bright_mae: 0.1834 - bright_mse: 0.0616 - bright_psnr: 13.2509 - bright_SSIM: 0.6407 - bright_AB: 0.1013 - LR =  0.0009900001
# 107/186 [================>.............] - ETA: 17:51 - loss: 3.0275 - bright_mae: 0.1828 - bright_mse: 0.0612 - bright_psnr: 13.2827 - bright_SSIM: 0.6420 - bright_AB: 0.1009 - LR =  0.0009900001
# 108/186 [================>.............] - ETA: 17:37 - loss: 3.0179 - bright_mae: 0.1823 - bright_mse: 0.0610 - bright_psnr: 13.2933 - bright_SSIM: 0.6433 - bright_AB: 0.1006 - LR =  0.0009900001
# 109/186 [================>.............] - ETA: 17:24 - loss: 3.0118 - bright_mae: 0.1816 - bright_mse: 0.0606 - bright_psnr: 13.3270 - bright_SSIM: 0.6443 - bright_AB: 0.1001 - LR =  0.0009900001
# 110/186 [================>.............] - ETA: 17:10 - loss: 3.0060 - bright_mae: 0.1812 - bright_mse: 0.0603 - bright_psnr: 13.3433 - bright_SSIM: 0.6449 - bright_AB: 0.0992 - LR =  0.0009900001
# 111/186 [================>.............] - ETA: 16:56 - loss: 3.0009 - bright_mae: 0.1807 - bright_mse: 0.0600 - bright_psnr: 13.3675 - bright_SSIM: 0.6456 - bright_AB: 0.0989 - LR =  0.0009900001
# 112/186 [=================>............] - ETA: 16:42 - loss: 2.9901 - bright_mae: 0.1800 - bright_mse: 0.0596 - bright_psnr: 13.4094 - bright_SSIM: 0.6471 - bright_AB: 0.0984 - LR =  0.0009900001
# 113/186 [=================>............] - ETA: 16:29 - loss: 2.9840 - bright_mae: 0.1794 - bright_mse: 0.0593 - bright_psnr: 13.4358 - bright_SSIM: 0.6481 - bright_AB: 0.0978 - LR =  0.0009900001
# 114/186 [=================>............] - ETA: 16:15 - loss: 2.9758 - bright_mae: 0.1792 - bright_mse: 0.0591 - bright_psnr: 13.4488 - bright_SSIM: 0.6492 - bright_AB: 0.0974 - LR =  0.0009900001
# 115/186 [=================>............] - ETA: 16:02 - loss: 2.9692 - bright_mae: 0.1790 - bright_mse: 0.0588 - bright_psnr: 13.4603 - bright_SSIM: 0.6499 - bright_AB: 0.0966 - LR =  0.0009900001
# 116/186 [=================>............] - ETA: 15:51 - loss: 2.9597 - bright_mae: 0.1783 - bright_mse: 0.0585 - bright_psnr: 13.4969 - bright_SSIM: 0.6512 - bright_AB: 0.0960 - LR =  0.0009900001
# 117/186 [=================>............] - ETA: 15:36 - loss: 2.9491 - bright_mae: 0.1780 - bright_mse: 0.0582 - bright_psnr: 13.5101 - bright_SSIM: 0.6528 - bright_AB: 0.0960 - LR =  0.0009900001
# 118/186 [==================>...........] - ETA: 15:28 - loss: 2.9406 - bright_mae: 0.1775 - bright_mse: 0.0579 - bright_psnr: 13.5340 - bright_SSIM: 0.6540 - bright_AB: 0.0954 - LR =  0.0009900001
# 119/186 [==================>...........] - ETA: 15:14 - loss: 2.9344 - bright_mae: 0.1771 - bright_mse: 0.0577 - bright_psnr: 13.5543 - bright_SSIM: 0.6546 - bright_AB: 0.0950 - LR =  0.0009900001
# 120/186 [==================>...........] - ETA: 15:02 - loss: 2.9263 - bright_mae: 0.1766 - bright_mse: 0.0574 - bright_psnr: 13.5756 - bright_SSIM: 0.6558 - bright_AB: 0.0947 - LR =  0.0009900001
# 121/186 [==================>...........] - ETA: 14:48 - loss: 2.9168 - bright_mae: 0.1761 - bright_mse: 0.0571 - bright_psnr: 13.6006 - bright_SSIM: 0.6572 - bright_AB: 0.0943 - LR =  0.0009900001
# 122/186 [==================>...........] - ETA: 14:34 - loss: 2.9096 - bright_mae: 0.1758 - bright_mse: 0.0569 - bright_psnr: 13.6150 - bright_SSIM: 0.6581 - bright_AB: 0.0937 - LR =  0.0009900001
# 123/186 [==================>...........] - ETA: 14:20 - loss: 2.9017 - bright_mae: 0.1753 - bright_mse: 0.0566 - bright_psnr: 13.6415 - bright_SSIM: 0.6591 - bright_AB: 0.0933 - LR =  0.0009900001
# 124/186 [===================>..........] - ETA: 14:05 - loss: 2.8949 - bright_mae: 0.1750 - bright_mse: 0.0564 - bright_psnr: 13.6453 - bright_SSIM: 0.6599 - bright_AB: 0.0932 - LR =  0.0009900001
# 125/186 [===================>..........] - ETA: 13:51 - loss: 2.8880 - bright_mae: 0.1748 - bright_mse: 0.0563 - bright_psnr: 13.6526 - bright_SSIM: 0.6609 - bright_AB: 0.0928 - LR =  0.0009900001
# 126/186 [===================>..........] - ETA: 13:40 - loss: 2.8789 - bright_mae: 0.1747 - bright_mse: 0.0561 - bright_psnr: 13.6631 - bright_SSIM: 0.6622 - bright_AB: 0.0931 - LR =  0.0009900001
# 127/186 [===================>..........] - ETA: 13:27 - loss: 2.8707 - bright_mae: 0.1742 - bright_mse: 0.0558 - bright_psnr: 13.6887 - bright_SSIM: 0.6633 - bright_AB: 0.0927 - LR =  0.0009900001
# 128/186 [===================>..........] - ETA: 13:13 - loss: 2.8636 - bright_mae: 0.1736 - bright_mse: 0.0555 - bright_psnr: 13.7245 - bright_SSIM: 0.6642 - bright_AB: 0.0921 - LR =  0.0009900001
# 129/186 [===================>..........] - ETA: 12:59 - loss: 2.8575 - bright_mae: 0.1736 - bright_mse: 0.0554 - bright_psnr: 13.7183 - bright_SSIM: 0.6652 - bright_AB: 0.0920 - LR =  0.0009900001
# 130/186 [===================>..........] - ETA: 12:45 - loss: 2.8528 - bright_mae: 0.1735 - bright_mse: 0.0553 - bright_psnr: 13.7174 - bright_SSIM: 0.6655 - bright_AB: 0.0914 - LR =  0.0009900001
# 131/186 [====================>.........] - ETA: 12:31 - loss: 2.8456 - bright_mae: 0.1732 - bright_mse: 0.0551 - bright_psnr: 13.7315 - bright_SSIM: 0.6664 - bright_AB: 0.0912 - LR =  0.0009900001
# 132/186 [====================>.........] - ETA: 12:18 - loss: 2.8420 - bright_mae: 0.1729 - bright_mse: 0.0549 - bright_psnr: 13.7448 - bright_SSIM: 0.6668 - bright_AB: 0.0908 - LR =  0.0009900001
# 133/186 [====================>.........] - ETA: 12:03 - loss: 2.8347 - bright_mae: 0.1724 - bright_mse: 0.0547 - bright_psnr: 13.7710 - bright_SSIM: 0.6679 - bright_AB: 0.0903 - LR =  0.0009900001
# 134/186 [====================>.........] - ETA: 11:50 - loss: 2.8287 - bright_mae: 0.1719 - bright_mse: 0.0544 - bright_psnr: 13.7984 - bright_SSIM: 0.6687 - bright_AB: 0.0899 - LR =  0.0009900001
# 135/186 [====================>.........] - ETA: 11:37 - loss: 2.8224 - bright_mae: 0.1716 - bright_mse: 0.0542 - bright_psnr: 13.8144 - bright_SSIM: 0.6693 - bright_AB: 0.0894 - LR =  0.0009900001
# 136/186 [====================>.........] - ETA: 11:23 - loss: 2.8146 - bright_mae: 0.1712 - bright_mse: 0.0539 - bright_psnr: 13.8436 - bright_SSIM: 0.6705 - bright_AB: 0.0888 - LR =  0.0009900001
# 137/186 [=====================>........] - ETA: 11:10 - loss: 2.8092 - bright_mae: 0.1708 - bright_mse: 0.0537 - bright_psnr: 13.8609 - bright_SSIM: 0.6712 - bright_AB: 0.0882 - LR =  0.0009900001
# 138/186 [=====================>........] - ETA: 10:56 - loss: 2.8039 - bright_mae: 0.1705 - bright_mse: 0.0535 - bright_psnr: 13.8776 - bright_SSIM: 0.6720 - bright_AB: 0.0879 - LR =  0.0009900001
# 139/186 [=====================>........] - ETA: 10:43 - loss: 2.7963 - bright_mae: 0.1700 - bright_mse: 0.0532 - bright_psnr: 13.9074 - bright_SSIM: 0.6730 - bright_AB: 0.0876 - LR =  0.0009900001
# 140/186 [=====================>........] - ETA: 10:29 - loss: 2.7907 - bright_mae: 0.1696 - bright_mse: 0.0530 - bright_psnr: 13.9277 - bright_SSIM: 0.6740 - bright_AB: 0.0873 - LR =  0.0009900001
# 141/186 [=====================>........] - ETA: 10:16 - loss: 2.7857 - bright_mae: 0.1696 - bright_mse: 0.0529 - bright_psnr: 13.9238 - bright_SSIM: 0.6748 - bright_AB: 0.0870 - LR =  0.0009900001
# 142/186 [=====================>........] - ETA: 10:02 - loss: 2.7794 - bright_mae: 0.1692 - bright_mse: 0.0527 - bright_psnr: 13.9411 - bright_SSIM: 0.6757 - bright_AB: 0.0866 - LR =  0.0009900001
# 143/186 [======================>.......] - ETA: 9:48 - loss: 2.7727 - bright_mae: 0.1690 - bright_mse: 0.0525 - bright_psnr: 13.9557 - bright_SSIM: 0.6767 - bright_AB: 0.0864  - LR =  0.0009900001
# 144/186 [======================>.......] - ETA: 9:39 - loss: 2.7664 - bright_mae: 0.1686 - bright_mse: 0.0523 - bright_psnr: 13.9728 - bright_SSIM: 0.6776 - bright_AB: 0.0859 - LR =  0.0009900001
# 145/186 [======================>.......] - ETA: 9:25 - loss: 2.7605 - bright_mae: 0.1683 - bright_mse: 0.0521 - bright_psnr: 13.9875 - bright_SSIM: 0.6785 - bright_AB: 0.0855 - LR =  0.0009900001
# 146/186 [======================>.......] - ETA: 9:11 - loss: 2.7557 - bright_mae: 0.1679 - bright_mse: 0.0519 - bright_psnr: 14.0050 - bright_SSIM: 0.6792 - bright_AB: 0.0851 - LR =  0.0009900001
# 147/186 [======================>.......] - ETA: 8:58 - loss: 2.7499 - bright_mae: 0.1678 - bright_mse: 0.0518 - bright_psnr: 14.0067 - bright_SSIM: 0.6800 - bright_AB: 0.0852 - LR =  0.0009900001
# 148/186 [======================>.......] - ETA: 8:44 - loss: 2.7446 - bright_mae: 0.1674 - bright_mse: 0.0516 - bright_psnr: 14.0294 - bright_SSIM: 0.6808 - bright_AB: 0.0849 - LR =  0.0009900001
# 149/186 [=======================>......] - ETA: 8:31 - loss: 2.7379 - bright_mae: 0.1669 - bright_mse: 0.0513 - bright_psnr: 14.0585 - bright_SSIM: 0.6816 - bright_AB: 0.0847 - LR =  0.0009900001
# 150/186 [=======================>......] - ETA: 8:17 - loss: 2.7330 - bright_mae: 0.1667 - bright_mse: 0.0512 - bright_psnr: 14.0646 - bright_SSIM: 0.6822 - bright_AB: 0.0849 - LR =  0.0009900001
# 151/186 [=======================>......] - ETA: 8:03 - loss: 2.7259 - bright_mae: 0.1663 - bright_mse: 0.0510 - bright_psnr: 14.0849 - bright_SSIM: 0.6832 - bright_AB: 0.0848 - LR =  0.0009900001
# 152/186 [=======================>......] - ETA: 7:49 - loss: 2.7221 - bright_mae: 0.1661 - bright_mse: 0.0508 - bright_psnr: 14.0934 - bright_SSIM: 0.6837 - bright_AB: 0.0844 - LR =  0.0009900001
# 153/186 [=======================>......] - ETA: 7:35 - loss: 2.7162 - bright_mae: 0.1657 - bright_mse: 0.0506 - bright_psnr: 14.1239 - bright_SSIM: 0.6845 - bright_AB: 0.0841 - LR =  0.0009900001
# 154/186 [=======================>......] - ETA: 7:21 - loss: 2.7132 - bright_mae: 0.1654 - bright_mse: 0.0504 - bright_psnr: 14.1379 - bright_SSIM: 0.6848 - bright_AB: 0.0841 - LR =  0.0009900001
# 155/186 [========================>.....] - ETA: 7:08 - loss: 2.7081 - bright_mae: 0.1650 - bright_mse: 0.0502 - bright_psnr: 14.1616 - bright_SSIM: 0.6855 - bright_AB: 0.0840 - LR =  0.0009900001
# 156/186 [========================>.....] - ETA: 6:54 - loss: 2.7055 - bright_mae: 0.1658 - bright_mse: 0.0507 - bright_psnr: 14.1269 - bright_SSIM: 0.6859 - bright_AB: 0.0853 - LR =  0.0009900001
# 157/186 [========================>.....] - ETA: 6:41 - loss: 2.7029 - bright_mae: 0.1657 - bright_mse: 0.0506 - bright_psnr: 14.1342 - bright_SSIM: 0.6859 - bright_AB: 0.0851 - LR =  0.0009900001
# 158/186 [========================>.....] - ETA: 6:27 - loss: 2.7014 - bright_mae: 0.1658 - bright_mse: 0.0506 - bright_psnr: 14.1270 - bright_SSIM: 0.6861 - bright_AB: 0.0854 - LR =  0.0009900001
# 159/186 [========================>.....] - ETA: 6:13 - loss: 2.7009 - bright_mae: 0.1661 - bright_mse: 0.0507 - bright_psnr: 14.1104 - bright_SSIM: 0.6861 - bright_AB: 0.0862 - LR =  0.0009900001
# 160/186 [========================>.....] - ETA: 5:59 - loss: 2.6990 - bright_mae: 0.1662 - bright_mse: 0.0507 - bright_psnr: 14.1066 - bright_SSIM: 0.6862 - bright_AB: 0.0864 - LR =  0.0009900001
# 161/186 [========================>.....] - ETA: 5:45 - loss: 2.6951 - bright_mae: 0.1664 - bright_mse: 0.0507 - bright_psnr: 14.0964 - bright_SSIM: 0.6867 - bright_AB: 0.0870 - LR =  0.0009900001
# 162/186 [=========================>....] - ETA: 5:31 - loss: 2.6922 - bright_mae: 0.1661 - bright_mse: 0.0506 - bright_psnr: 14.1082 - bright_SSIM: 0.6872 - bright_AB: 0.0866 - LR =  0.0009900001
# 163/186 [=========================>....] - ETA: 5:17 - loss: 2.6899 - bright_mae: 0.1663 - bright_mse: 0.0506 - bright_psnr: 14.0966 - bright_SSIM: 0.6877 - bright_AB: 0.0872 - LR =  0.0009900001
# 164/186 [=========================>....] - ETA: 5:03 - loss: 2.6893 - bright_mae: 0.1667 - bright_mse: 0.0508 - bright_psnr: 14.0794 - bright_SSIM: 0.6876 - bright_AB: 0.0872 - LR =  0.0009900001
# 165/186 [=========================>....] - ETA: 4:49 - loss: 2.6855 - bright_mae: 0.1666 - bright_mse: 0.0506 - bright_psnr: 14.0870 - bright_SSIM: 0.6881 - bright_AB: 0.0867 - LR =  0.0009900001
# 166/186 [=========================>....] - ETA: 4:35 - loss: 2.6842 - bright_mae: 0.1666 - bright_mse: 0.0506 - bright_psnr: 14.0858 - bright_SSIM: 0.6883 - bright_AB: 0.0867 - LR =  0.0009900001
# 167/186 [=========================>....] - ETA: 4:21 - loss: 2.6807 - bright_mae: 0.1665 - bright_mse: 0.0505 - bright_psnr: 14.0893 - bright_SSIM: 0.6887 - bright_AB: 0.0867 - LR =  0.0009900001
# 168/186 [==========================>...] - ETA: 4:08 - loss: 2.6797 - bright_mae: 0.1663 - bright_mse: 0.0503 - bright_psnr: 14.0986 - bright_SSIM: 0.6888 - bright_AB: 0.0863 - LR =  0.0009900001
# 169/186 [==========================>...] - ETA: 3:54 - loss: 2.6767 - bright_mae: 0.1660 - bright_mse: 0.0502 - bright_psnr: 14.1150 - bright_SSIM: 0.6893 - bright_AB: 0.0858 - LR =  0.0009900001
# 170/186 [==========================>...] - ETA: 3:40 - loss: 2.6745 - bright_mae: 0.1660 - bright_mse: 0.0501 - bright_psnr: 14.1167 - bright_SSIM: 0.6896 - bright_AB: 0.0859 - LR =  0.0009900001
# 171/186 [==========================>...] - ETA: 3:27 - loss: 2.6704 - bright_mae: 0.1660 - bright_mse: 0.0500 - bright_psnr: 14.1142 - bright_SSIM: 0.6903 - bright_AB: 0.0861 - LR =  0.0009900001
# 172/186 [==========================>...] - ETA: 3:13 - loss: 2.6670 - bright_mae: 0.1657 - bright_mse: 0.0499 - bright_psnr: 14.1269 - bright_SSIM: 0.6908 - bright_AB: 0.0858 - LR =  0.0009900001
# 173/186 [==========================>...] - ETA: 2:59 - loss: 2.6652 - bright_mae: 0.1657 - bright_mse: 0.0499 - bright_psnr: 14.1240 - bright_SSIM: 0.6909 - bright_AB: 0.0861 - LR =  0.0009900001
# 174/186 [===========================>..] - ETA: 2:45 - loss: 2.6610 - bright_mae: 0.1656 - bright_mse: 0.0498 - bright_psnr: 14.1249 - bright_SSIM: 0.6915 - bright_AB: 0.0863 - LR =  0.0009900001
# 175/186 [===========================>..] - ETA: 2:31 - loss: 2.6584 - bright_mae: 0.1655 - bright_mse: 0.0497 - bright_psnr: 14.1295 - bright_SSIM: 0.6919 - bright_AB: 0.0862 - LR =  0.0009900001
# 176/186 [===========================>..] - ETA: 2:17 - loss: 2.6554 - bright_mae: 0.1655 - bright_mse: 0.0497 - bright_psnr: 14.1252 - bright_SSIM: 0.6924 - bright_AB: 0.0861 - LR =  0.0009900001
# 177/186 [===========================>..] - ETA: 2:04 - loss: 2.6522 - bright_mae: 0.1656 - bright_mse: 0.0496 - bright_psnr: 14.1215 - bright_SSIM: 0.6929 - bright_AB: 0.0866 - LR =  0.0009900001
# 178/186 [===========================>..] - ETA: 1:50 - loss: 2.6493 - bright_mae: 0.1654 - bright_mse: 0.0495 - bright_psnr: 14.1354 - bright_SSIM: 0.6934 - bright_AB: 0.0862 - LR =  0.0009900001
# 179/186 [===========================>..] - ETA: 1:36 - loss: 2.6459 - bright_mae: 0.1653 - bright_mse: 0.0494 - bright_psnr: 14.1392 - bright_SSIM: 0.6938 - bright_AB: 0.0861 - LR =  0.0009900001
# 180/186 [============================>.] - ETA: 1:23 - loss: 2.6429 - bright_mae: 0.1651 - bright_mse: 0.0492 - bright_psnr: 14.1509 - bright_SSIM: 0.6943 - bright_AB: 0.0860 - LR =  0.0009900001
# 181/186 [============================>.] - ETA: 1:09 - loss: 2.6403 - bright_mae: 0.1649 - bright_mse: 0.0491 - bright_psnr: 14.1620 - bright_SSIM: 0.6946 - bright_AB: 0.0857 - LR =  0.0009900001
# 182/186 [============================>.] - ETA: 55s - loss: 2.6370 - bright_mae: 0.1646 - bright_mse: 0.0490 - bright_psnr: 14.1732 - bright_SSIM: 0.6951 - bright_AB: 0.0853  - LR =  0.0009900001
# 183/186 [============================>.] - ETA: 41s - loss: 2.6347 - bright_mae: 0.1646 - bright_mse: 0.0489 - bright_psnr: 14.1728 - bright_SSIM: 0.6954 - bright_AB: 0.0851 - LR =  0.0009900001
# 184/186 [============================>.] - ETA: 27s - loss: 2.6306 - bright_mae: 0.1644 - bright_mse: 0.0488 - bright_psnr: 14.1804 - bright_SSIM: 0.6960 - bright_AB: 0.0851 - LR =  0.0009900001
# 185/186 [============================>.] - ETA: 13s - loss: 2.6255 - bright_mae: 0.1640 - bright_mse: 0.0486 - bright_psnr: 14.1999 - bright_SSIM: 0.6968 - bright_AB: 0.0848 - LR =  0.0009900001
# ------------------------------------------------
# [Epoch 1]  [PSNR_AVE :8.684680]
# ------------------------------------------------
# 186/186 [==============================] - 2593s 14s/step - loss: 2.6242 - bright_mae: 0.1639 - bright_mse: 0.0485 - bright_psnr: 14.2054 - bright_SSIM: 0.6969 - bright_AB: 0.0846
# LR = 0.0009900001
# Epoch 2/20
#  - LR =  0.0009801001
#   1/186 [..............................] - ETA: 3:43 - loss: 2.1919 - bright_mae: 0.1542 - bright_mse: 0.0365 - bright_psnr: 14.3717 - bright_SSIM: 0.7722 - bright_AB: 0.0370 - LR =  0.0009801001
#   2/186 [..............................] - ETA: 3:41 - loss: 2.1247 - bright_mae: 0.1324 - bright_mse: 0.0274 - bright_psnr: 15.8848 - bright_SSIM: 0.7705 - bright_AB: 0.0313 - LR =  0.0009801001
#   3/186 [..............................] - ETA: 3:39 - loss: 2.1710 - bright_mae: 0.1265 - bright_mse: 0.0259 - bright_psnr: 16.0453 - bright_SSIM: 0.7558 - bright_AB: 0.0354 - LR =  0.0009801001
#   4/186 [..............................] - ETA: 3:38 - loss: 2.0200 - bright_mae: 0.1145 - bright_mse: 0.0218 - bright_psnr: 17.0859 - bright_SSIM: 0.7783 - bright_AB: 0.0363 - LR =  0.0009801001
#   5/186 [..............................] - ETA: 3:36 - loss: 2.0521 - bright_mae: 0.1156 - bright_mse: 0.0225 - bright_psnr: 16.8693 - bright_SSIM: 0.7741 - bright_AB: 0.0383 - LR =  0.0009801001
#   6/186 [..............................] - ETA: 3:35 - loss: 2.0572 - bright_mae: 0.1256 - bright_mse: 0.0263 - bright_psnr: 16.2938 - bright_SSIM: 0.7731 - bright_AB: 0.0413 - LR =  0.0009801001
#   7/186 [>.............................] - ETA: 3:34 - loss: 2.0805 - bright_mae: 0.1236 - bright_mse: 0.0253 - bright_psnr: 16.4252 - bright_SSIM: 0.7701 - bright_AB: 0.0365 - LR =  0.0009801001
#   8/186 [>.............................] - ETA: 3:32 - loss: 2.0385 - bright_mae: 0.1209 - bright_mse: 0.0244 - bright_psnr: 16.5573 - bright_SSIM: 0.7763 - bright_AB: 0.0350 - LR =  0.0009801001
#   9/186 [>.............................] - ETA: 3:31 - loss: 2.0400 - bright_mae: 0.1172 - bright_mse: 0.0232 - bright_psnr: 16.7673 - bright_SSIM: 0.7726 - bright_AB: 0.0345 - LR =  0.0009801001
#  10/186 [>.............................] - ETA: 3:30 - loss: 2.0713 - bright_mae: 0.1236 - bright_mse: 0.0256 - bright_psnr: 16.4198 - bright_SSIM: 0.7684 - bright_AB: 0.0398 - LR =  0.0009801001
#  11/186 [>.............................] - ETA: 3:29 - loss: 2.0639 - bright_mae: 0.1226 - bright_mse: 0.0251 - bright_psnr: 16.4621 - bright_SSIM: 0.7704 - bright_AB: 0.0413 - LR =  0.0009801001
#  12/186 [>.............................] - ETA: 3:28 - loss: 2.0310 - bright_mae: 0.1224 - bright_mse: 0.0248 - bright_psnr: 16.4917 - bright_SSIM: 0.7747 - bright_AB: 0.0435 - LR =  0.0009801001
#  13/186 [=>............................] - ETA: 3:27 - loss: 2.0292 - bright_mae: 0.1248 - bright_mse: 0.0257 - bright_psnr: 16.3216 - bright_SSIM: 0.7757 - bright_AB: 0.0490 - LR =  0.0009801001
#  14/186 [=>............................] - ETA: 3:26 - loss: 2.0285 - bright_mae: 0.1260 - bright_mse: 0.0259 - bright_psnr: 16.2681 - bright_SSIM: 0.7752 - bright_AB: 0.0513 - LR =  0.0009801001
#  15/186 [=>............................] - ETA: 3:24 - loss: 2.0379 - bright_mae: 0.1256 - bright_mse: 0.0257 - bright_psnr: 16.2805 - bright_SSIM: 0.7739 - bright_AB: 0.0485 - LR =  0.0009801001
#  16/186 [=>............................] - ETA: 3:23 - loss: 2.0341 - bright_mae: 0.1241 - bright_mse: 0.0250 - bright_psnr: 16.3993 - bright_SSIM: 0.7751 - bright_AB: 0.0473 - LR =  0.0009801001
#  17/186 [=>............................] - ETA: 3:22 - loss: 2.0320 - bright_mae: 0.1237 - bright_mse: 0.0247 - bright_psnr: 16.4287 - bright_SSIM: 0.7749 - bright_AB: 0.0451 - LR =  0.0009801001
#  18/186 [=>............................] - ETA: 3:21 - loss: 2.0507 - bright_mae: 0.1239 - bright_mse: 0.0249 - bright_psnr: 16.3895 - bright_SSIM: 0.7720 - bright_AB: 0.0451 - LR =  0.0009801001
#  19/186 [==>...........................] - ETA: 3:20 - loss: 2.0396 - bright_mae: 0.1238 - bright_mse: 0.0250 - bright_psnr: 16.3545 - bright_SSIM: 0.7735 - bright_AB: 0.0482 - LR =  0.0009801001
#  20/186 [==>...........................] - ETA: 3:18 - loss: 2.0109 - bright_mae: 0.1227 - bright_mse: 0.0246 - bright_psnr: 16.4003 - bright_SSIM: 0.7772 - bright_AB: 0.0463 - LR =  0.0009801001
#  21/186 [==>...........................] - ETA: 3:17 - loss: 2.0088 - bright_mae: 0.1234 - bright_mse: 0.0248 - bright_psnr: 16.3518 - bright_SSIM: 0.7779 - bright_AB: 0.0490 - LR =  0.0009801001
#  22/186 [==>...........................] - ETA: 3:16 - loss: 2.0135 - bright_mae: 0.1249 - bright_mse: 0.0253 - bright_psnr: 16.2724 - bright_SSIM: 0.7778 - bright_AB: 0.0512 - LR =  0.0009801001
#  23/186 [==>...........................] - ETA: 3:15 - loss: 2.0250 - bright_mae: 0.1268 - bright_mse: 0.0260 - bright_psnr: 16.1653 - bright_SSIM: 0.7750 - bright_AB: 0.0546 - LR =  0.0009801001
#  24/186 [==>...........................] - ETA: 3:14 - loss: 2.0110 - bright_mae: 0.1265 - bright_mse: 0.0260 - bright_psnr: 16.1528 - bright_SSIM: 0.7771 - bright_AB: 0.0554 - LR =  0.0009801001
#  25/186 [===>..........................] - ETA: 3:13 - loss: 2.0206 - bright_mae: 0.1301 - bright_mse: 0.0273 - bright_psnr: 15.9979 - bright_SSIM: 0.7757 - bright_AB: 0.0588 - LR =  0.0009801001
#  26/186 [===>..........................] - ETA: 3:11 - loss: 2.0369 - bright_mae: 0.1323 - bright_mse: 0.0281 - bright_psnr: 15.8905 - bright_SSIM: 0.7733 - bright_AB: 0.0568 - LR =  0.0009801001
#  27/186 [===>..........................] - ETA: 3:10 - loss: 2.0410 - bright_mae: 0.1323 - bright_mse: 0.0281 - bright_psnr: 15.8749 - bright_SSIM: 0.7733 - bright_AB: 0.0556 - LR =  0.0009801001
# ...
# 107/186 [================>.............] - ETA: 1:36 - loss: 1.3778 - bright_mae: 0.1025 - bright_mse: 0.0180 - bright_psnr: 17.6878 - bright_SSIM: 0.8487 - bright_AB: 0.0263 - LR =  1.27797975e-05
# 108/186 [================>.............] - ETA: 1:35 - loss: 1.3789 - bright_mae: 0.1028 - bright_mse: 0.0181 - bright_psnr: 17.6644 - bright_SSIM: 0.8485 - bright_AB: 0.0262 - LR =  1.27797975e-05
# 109/186 [================>.............] - ETA: 1:34 - loss: 1.3779 - bright_mae: 0.1029 - bright_mse: 0.0181 - bright_psnr: 17.6561 - bright_SSIM: 0.8488 - bright_AB: 0.0260 - LR =  1.27797975e-05
# 110/186 [================>.............] - ETA: 1:33 - loss: 1.3810 - bright_mae: 0.1034 - bright_mse: 0.0183 - bright_psnr: 17.6252 - bright_SSIM: 0.8485 - bright_AB: 0.0263 - LR =  1.27797975e-05
# 111/186 [================>.............] - ETA: 1:31 - loss: 1.3829 - bright_mae: 0.1035 - bright_mse: 0.0183 - bright_psnr: 17.6235 - bright_SSIM: 0.8481 - bright_AB: 0.0260 - LR =  1.27797975e-05
# 112/186 [=================>............] - ETA: 1:30 - loss: 1.3840 - bright_mae: 0.1037 - bright_mse: 0.0184 - bright_psnr: 17.6089 - bright_SSIM: 0.8479 - bright_AB: 0.0262 - LR =  1.27797975e-05
# 113/186 [=================>............] - ETA: 1:29 - loss: 1.3820 - bright_mae: 0.1036 - bright_mse: 0.0183 - bright_psnr: 17.6215 - bright_SSIM: 0.8482 - bright_AB: 0.0260 - LR =  1.27797975e-05
# 114/186 [=================>............] - ETA: 1:28 - loss: 1.3821 - bright_mae: 0.1035 - bright_mse: 0.0183 - bright_psnr: 17.6264 - bright_SSIM: 0.8484 - bright_AB: 0.0262 - LR =  1.27797975e-05
# 115/186 [=================>............] - ETA: 1:27 - loss: 1.3814 - bright_mae: 0.1036 - bright_mse: 0.0183 - bright_psnr: 17.6275 - bright_SSIM: 0.8486 - bright_AB: 0.0261 - LR =  1.27797975e-05
# 116/186 [=================>............] - ETA: 1:25 - loss: 1.3867 - bright_mae: 0.1038 - bright_mse: 0.0184 - bright_psnr: 17.6065 - bright_SSIM: 0.8478 - bright_AB: 0.0263 - LR =  1.27797975e-05
# 117/186 [=================>............] - ETA: 1:24 - loss: 1.3861 - bright_mae: 0.1037 - bright_mse: 0.0183 - bright_psnr: 17.6128 - bright_SSIM: 0.8479 - bright_AB: 0.0264 - LR =  1.27797975e-05
# 118/186 [==================>...........] - ETA: 1:23 - loss: 1.3857 - bright_mae: 0.1038 - bright_mse: 0.0183 - bright_psnr: 17.6107 - bright_SSIM: 0.8479 - bright_AB: 0.0264 - LR =  1.27797975e-05
# 119/186 [==================>...........] - ETA: 1:22 - loss: 1.3857 - bright_mae: 0.1037 - bright_mse: 0.0183 - bright_psnr: 17.6158 - bright_SSIM: 0.8480 - bright_AB: 0.0265 - LR =  1.27797975e-05
# 120/186 [==================>...........] - ETA: 1:20 - loss: 1.3847 - bright_mae: 0.1037 - bright_mse: 0.0183 - bright_psnr: 17.6143 - bright_SSIM: 0.8482 - bright_AB: 0.0262 - LR =  1.27797975e-05
# 121/186 [==================>...........] - ETA: 1:19 - loss: 1.3880 - bright_mae: 0.1041 - bright_mse: 0.0184 - bright_psnr: 17.5903 - bright_SSIM: 0.8475 - bright_AB: 0.0264 - LR =  1.27797975e-05
# 122/186 [==================>...........] - ETA: 1:18 - loss: 1.3868 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.5964 - bright_SSIM: 0.8478 - bright_AB: 0.0266 - LR =  1.27797975e-05
# 123/186 [==================>...........] - ETA: 1:17 - loss: 1.3876 - bright_mae: 0.1039 - bright_mse: 0.0184 - bright_psnr: 17.6074 - bright_SSIM: 0.8476 - bright_AB: 0.0264 - LR =  1.27797975e-05
# 124/186 [===================>..........] - ETA: 1:16 - loss: 1.3875 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.5989 - bright_SSIM: 0.8477 - bright_AB: 0.0265 - LR =  1.27797975e-05
# 125/186 [===================>..........] - ETA: 1:14 - loss: 1.3881 - bright_mae: 0.1043 - bright_mse: 0.0185 - bright_psnr: 17.5831 - bright_SSIM: 0.8476 - bright_AB: 0.0265 - LR =  1.27797975e-05
# 126/186 [===================>..........] - ETA: 1:13 - loss: 1.3864 - bright_mae: 0.1041 - bright_mse: 0.0184 - bright_psnr: 17.5970 - bright_SSIM: 0.8479 - bright_AB: 0.0265 - LR =  1.27797975e-05
# 127/186 [===================>..........] - ETA: 1:12 - loss: 1.3874 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.5971 - bright_SSIM: 0.8477 - bright_AB: 0.0265 - LR =  1.27797975e-05
# 128/186 [===================>..........] - ETA: 1:11 - loss: 1.3873 - bright_mae: 0.1038 - bright_mse: 0.0184 - bright_psnr: 17.6107 - bright_SSIM: 0.8478 - bright_AB: 0.0265 - LR =  1.27797975e-05
# 129/186 [===================>..........] - ETA: 1:09 - loss: 1.3897 - bright_mae: 0.1042 - bright_mse: 0.0185 - bright_psnr: 17.5888 - bright_SSIM: 0.8476 - bright_AB: 0.0266 - LR =  1.27797975e-05
# 130/186 [===================>..........] - ETA: 1:08 - loss: 1.3898 - bright_mae: 0.1041 - bright_mse: 0.0184 - bright_psnr: 17.5946 - bright_SSIM: 0.8475 - bright_AB: 0.0265 - LR =  1.27797975e-05
# 131/186 [====================>.........] - ETA: 1:07 - loss: 1.3896 - bright_mae: 0.1043 - bright_mse: 0.0185 - bright_psnr: 17.5844 - bright_SSIM: 0.8476 - bright_AB: 0.0267 - LR =  1.27797975e-05
# 132/186 [====================>.........] - ETA: 1:06 - loss: 1.3880 - bright_mae: 0.1043 - bright_mse: 0.0185 - bright_psnr: 17.5851 - bright_SSIM: 0.8478 - bright_AB: 0.0270 - LR =  1.27797975e-05
# 133/186 [====================>.........] - ETA: 1:05 - loss: 1.3869 - bright_mae: 0.1042 - bright_mse: 0.0184 - bright_psnr: 17.5976 - bright_SSIM: 0.8479 - bright_AB: 0.0270 - LR =  1.27797975e-05
# 134/186 [====================>.........] - ETA: 1:03 - loss: 1.3883 - bright_mae: 0.1045 - bright_mse: 0.0185 - bright_psnr: 17.5799 - bright_SSIM: 0.8477 - bright_AB: 0.0275 - LR =  1.27797975e-05
# 135/186 [====================>.........] - ETA: 1:02 - loss: 1.3894 - bright_mae: 0.1046 - bright_mse: 0.0185 - bright_psnr: 17.5702 - bright_SSIM: 0.8476 - bright_AB: 0.0281 - LR =  1.27797975e-05
# 136/186 [====================>.........] - ETA: 1:01 - loss: 1.3885 - bright_mae: 0.1044 - bright_mse: 0.0185 - bright_psnr: 17.5805 - bright_SSIM: 0.8479 - bright_AB: 0.0279 - LR =  1.27797975e-05
# 137/186 [=====================>........] - ETA: 1:00 - loss: 1.3891 - bright_mae: 0.1042 - bright_mse: 0.0184 - bright_psnr: 17.6010 - bright_SSIM: 0.8478 - bright_AB: 0.0277 - LR =  1.27797975e-05
# 138/186 [=====================>........] - ETA: 58s - loss: 1.3880 - bright_mae: 0.1041 - bright_mse: 0.0184 - bright_psnr: 17.6041 - bright_SSIM: 0.8480 - bright_AB: 0.0279  - LR =  1.27797975e-05
# 139/186 [=====================>........] - ETA: 57s - loss: 1.3861 - bright_mae: 0.1042 - bright_mse: 0.0184 - bright_psnr: 17.5951 - bright_SSIM: 0.8484 - bright_AB: 0.0280 - LR =  1.27797975e-05
# 140/186 [=====================>........] - ETA: 56s - loss: 1.3872 - bright_mae: 0.1042 - bright_mse: 0.0184 - bright_psnr: 17.5970 - bright_SSIM: 0.8483 - bright_AB: 0.0281 - LR =  1.27797975e-05
# 141/186 [=====================>........] - ETA: 55s - loss: 1.3881 - bright_mae: 0.1044 - bright_mse: 0.0185 - bright_psnr: 17.5817 - bright_SSIM: 0.8481 - bright_AB: 0.0284 - LR =  1.27797975e-05
# 142/186 [=====================>........] - ETA: 53s - loss: 1.3881 - bright_mae: 0.1045 - bright_mse: 0.0185 - bright_psnr: 17.5743 - bright_SSIM: 0.8480 - bright_AB: 0.0285 - LR =  1.27797975e-05
# 143/186 [======================>.......] - ETA: 52s - loss: 1.3868 - bright_mae: 0.1044 - bright_mse: 0.0185 - bright_psnr: 17.5820 - bright_SSIM: 0.8483 - bright_AB: 0.0283 - LR =  1.27797975e-05
# 144/186 [======================>.......] - ETA: 51s - loss: 1.3891 - bright_mae: 0.1044 - bright_mse: 0.0185 - bright_psnr: 17.5747 - bright_SSIM: 0.8478 - bright_AB: 0.0284 - LR =  1.27797975e-05
# 145/186 [======================>.......] - ETA: 50s - loss: 1.3886 - bright_mae: 0.1043 - bright_mse: 0.0185 - bright_psnr: 17.5861 - bright_SSIM: 0.8479 - bright_AB: 0.0285 - LR =  1.27797975e-05
# 146/186 [======================>.......] - ETA: 49s - loss: 1.3866 - bright_mae: 0.1042 - bright_mse: 0.0184 - bright_psnr: 17.5935 - bright_SSIM: 0.8482 - bright_AB: 0.0284 - LR =  1.27797975e-05
# 147/186 [======================>.......] - ETA: 47s - loss: 1.3843 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.6133 - bright_SSIM: 0.8486 - bright_AB: 0.0282 - LR =  1.27797975e-05
# 148/186 [======================>.......] - ETA: 46s - loss: 1.3846 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.6124 - bright_SSIM: 0.8485 - bright_AB: 0.0282 - LR =  1.27797975e-05
# 149/186 [=======================>......] - ETA: 45s - loss: 1.3845 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.6096 - bright_SSIM: 0.8485 - bright_AB: 0.0283 - LR =  1.27797975e-05
# 150/186 [=======================>......] - ETA: 44s - loss: 1.3843 - bright_mae: 0.1041 - bright_mse: 0.0184 - bright_psnr: 17.6013 - bright_SSIM: 0.8485 - bright_AB: 0.0285 - LR =  1.27797975e-05
# 151/186 [=======================>......] - ETA: 42s - loss: 1.3835 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.6047 - bright_SSIM: 0.8487 - bright_AB: 0.0284 - LR =  1.27797975e-05
# 152/186 [=======================>......] - ETA: 41s - loss: 1.3824 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.6122 - bright_SSIM: 0.8489 - bright_AB: 0.0283 - LR =  1.27797975e-05
# 153/186 [=======================>......] - ETA: 40s - loss: 1.3827 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.6072 - bright_SSIM: 0.8490 - bright_AB: 0.0283 - LR =  1.27797975e-05
# 154/186 [=======================>......] - ETA: 39s - loss: 1.3844 - bright_mae: 0.1041 - bright_mse: 0.0184 - bright_psnr: 17.5970 - bright_SSIM: 0.8487 - bright_AB: 0.0281 - LR =  1.27797975e-05
# 155/186 [========================>.....] - ETA: 38s - loss: 1.3833 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.6100 - bright_SSIM: 0.8488 - bright_AB: 0.0280 - LR =  1.27797975e-05
# 156/186 [========================>.....] - ETA: 36s - loss: 1.3846 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.6109 - bright_SSIM: 0.8486 - bright_AB: 0.0279 - LR =  1.27797975e-05
# 157/186 [========================>.....] - ETA: 35s - loss: 1.3824 - bright_mae: 0.1037 - bright_mse: 0.0183 - bright_psnr: 17.6406 - bright_SSIM: 0.8489 - bright_AB: 0.0278 - LR =  1.27797975e-05
# 158/186 [========================>.....] - ETA: 34s - loss: 1.3817 - bright_mae: 0.1037 - bright_mse: 0.0183 - bright_psnr: 17.6393 - bright_SSIM: 0.8490 - bright_AB: 0.0281 - LR =  1.27797975e-05
# 159/186 [========================>.....] - ETA: 33s - loss: 1.3808 - bright_mae: 0.1038 - bright_mse: 0.0183 - bright_psnr: 17.6374 - bright_SSIM: 0.8492 - bright_AB: 0.0281 - LR =  1.27797975e-05
# 160/186 [========================>.....] - ETA: 31s - loss: 1.3817 - bright_mae: 0.1038 - bright_mse: 0.0183 - bright_psnr: 17.6363 - bright_SSIM: 0.8491 - bright_AB: 0.0281 - LR =  1.27797975e-05
# 161/186 [========================>.....] - ETA: 30s - loss: 1.3806 - bright_mae: 0.1038 - bright_mse: 0.0183 - bright_psnr: 17.6377 - bright_SSIM: 0.8492 - bright_AB: 0.0284 - LR =  1.27797975e-05
# 162/186 [=========================>....] - ETA: 29s - loss: 1.3831 - bright_mae: 0.1040 - bright_mse: 0.0184 - bright_psnr: 17.6193 - bright_SSIM: 0.8489 - bright_AB: 0.0284 - LR =  1.27797975e-05
# 163/186 [=========================>....] - ETA: 28s - loss: 1.3828 - bright_mae: 0.1039 - bright_mse: 0.0183 - bright_psnr: 17.6253 - bright_SSIM: 0.8489 - bright_AB: 0.0283 - LR =  1.27797975e-05
# 164/186 [=========================>....] - ETA: 26s - loss: 1.3827 - bright_mae: 0.1039 - bright_mse: 0.0183 - bright_psnr: 17.6252 - bright_SSIM: 0.8490 - bright_AB: 0.0283 - LR =  1.27797975e-05
# 165/186 [=========================>....] - ETA: 25s - loss: 1.3810 - bright_mae: 0.1037 - bright_mse: 0.0183 - bright_psnr: 17.6371 - bright_SSIM: 0.8492 - bright_AB: 0.0282 - LR =  1.27797975e-05
# 166/186 [=========================>....] - ETA: 24s - loss: 1.3799 - bright_mae: 0.1037 - bright_mse: 0.0183 - bright_psnr: 17.6435 - bright_SSIM: 0.8493 - bright_AB: 0.0282 - LR =  1.27797975e-05
# 167/186 [=========================>....] - ETA: 23s - loss: 1.3802 - bright_mae: 0.1036 - bright_mse: 0.0183 - bright_psnr: 17.6424 - bright_SSIM: 0.8491 - bright_AB: 0.0281 - LR =  1.27797975e-05
# 168/186 [==========================>...] - ETA: 22s - loss: 1.3820 - bright_mae: 0.1039 - bright_mse: 0.0184 - bright_psnr: 17.6230 - bright_SSIM: 0.8488 - bright_AB: 0.0282 - LR =  1.27797975e-05
# 169/186 [==========================>...] - ETA: 20s - loss: 1.3820 - bright_mae: 0.1037 - bright_mse: 0.0183 - bright_psnr: 17.6333 - bright_SSIM: 0.8488 - bright_AB: 0.0281 - LR =  1.27797975e-05
# 170/186 [==========================>...] - ETA: 19s - loss: 1.3820 - bright_mae: 0.1036 - bright_mse: 0.0183 - bright_psnr: 17.6385 - bright_SSIM: 0.8488 - bright_AB: 0.0281 - LR =  1.27797975e-05
# 171/186 [==========================>...] - ETA: 18s - loss: 1.3822 - bright_mae: 0.1038 - bright_mse: 0.0184 - bright_psnr: 17.6257 - bright_SSIM: 0.8488 - bright_AB: 0.0285 - LR =  1.27797975e-05
# 172/186 [==========================>...] - ETA: 17s - loss: 1.3830 - bright_mae: 0.1037 - bright_mse: 0.0183 - bright_psnr: 17.6285 - bright_SSIM: 0.8487 - bright_AB: 0.0283 - LR =  1.27797975e-05
# 173/186 [==========================>...] - ETA: 15s - loss: 1.3828 - bright_mae: 0.1037 - bright_mse: 0.0183 - bright_psnr: 17.6280 - bright_SSIM: 0.8487 - bright_AB: 0.0285 - LR =  1.27797975e-05
# 174/186 [===========================>..] - ETA: 14s - loss: 1.3818 - bright_mae: 0.1036 - bright_mse: 0.0183 - bright_psnr: 17.6388 - bright_SSIM: 0.8488 - bright_AB: 0.0285 - LR =  1.27797975e-05
# 175/186 [===========================>..] - ETA: 13s - loss: 1.3828 - bright_mae: 0.1035 - bright_mse: 0.0183 - bright_psnr: 17.6482 - bright_SSIM: 0.8487 - bright_AB: 0.0283 - LR =  1.27797975e-05
# 176/186 [===========================>..] - ETA: 12s - loss: 1.3815 - bright_mae: 0.1035 - bright_mse: 0.0183 - bright_psnr: 17.6463 - bright_SSIM: 0.8489 - bright_AB: 0.0285 - LR =  1.27797975e-05
# 177/186 [===========================>..] - ETA: 11s - loss: 1.3790 - bright_mae: 0.1033 - bright_mse: 0.0182 - bright_psnr: 17.6635 - bright_SSIM: 0.8493 - bright_AB: 0.0285 - LR =  1.27797975e-05
# 178/186 [===========================>..] - ETA: 9s - loss: 1.3789 - bright_mae: 0.1032 - bright_mse: 0.0182 - bright_psnr: 17.6705 - bright_SSIM: 0.8494 - bright_AB: 0.0287  - LR =  1.27797975e-05
# 179/186 [===========================>..] - ETA: 8s - loss: 1.3784 - bright_mae: 0.1033 - bright_mse: 0.0182 - bright_psnr: 17.6651 - bright_SSIM: 0.8495 - bright_AB: 0.0287 - LR =  1.27797975e-05
# 180/186 [============================>.] - ETA: 7s - loss: 1.3806 - bright_mae: 0.1035 - bright_mse: 0.0182 - bright_psnr: 17.6545 - bright_SSIM: 0.8491 - bright_AB: 0.0285 - LR =  1.27797975e-05
# 181/186 [============================>.] - ETA: 6s - loss: 1.3814 - bright_mae: 0.1035 - bright_mse: 0.0182 - bright_psnr: 17.6523 - bright_SSIM: 0.8490 - bright_AB: 0.0285 - LR =  1.27797975e-05
# 182/186 [============================>.] - ETA: 4s - loss: 1.3818 - bright_mae: 0.1036 - bright_mse: 0.0183 - bright_psnr: 17.6478 - bright_SSIM: 0.8490 - bright_AB: 0.0284 - LR =  1.27797975e-05
# 183/186 [============================>.] - ETA: 3s - loss: 1.3821 - bright_mae: 0.1037 - bright_mse: 0.0183 - bright_psnr: 17.6425 - bright_SSIM: 0.8490 - bright_AB: 0.0286 - LR =  1.27797975e-05
# 184/186 [============================>.] - ETA: 2s - loss: 1.3826 - bright_mae: 0.1039 - bright_mse: 0.0183 - bright_psnr: 17.6310 - bright_SSIM: 0.8490 - bright_AB: 0.0286 - LR =  1.27797975e-05
# 185/186 [============================>.] - ETA: 1s - loss: 1.3838 - bright_mae: 0.1039 - bright_mse: 0.0183 - bright_psnr: 17.6316 - bright_SSIM: 0.8488 - bright_AB: 0.0285 - LR =  1.27797975e-05
# ------------------------------------------------
# [Epoch 20]  [PSNR_AVE :8.056068]
# ------------------------------------------------
# 186/186 [==============================] - 231s 1s/step - loss: 1.3850 - bright_mae: 0.1039 - bright_mse: 0.0183 - bright_psnr: 17.6279 - bright_SSIM: 0.8486 - bright_AB: 0.0286
# Done!
